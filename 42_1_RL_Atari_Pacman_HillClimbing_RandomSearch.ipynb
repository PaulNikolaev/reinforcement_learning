# %% [markdown]
# # Задание
#
# 1. Используя Gym Atari, выберите любую игру с более чем 4-мя действиями.
# 2. Обучите игру на стратегиях случайного поиска и восхождения на вершину.
# 3. Создайте видео с наибольшим вознаграждением и вставьте его в колаб.

# %%
#@title Установка зависимостей
# !pip install "gymnasium[atari]"
# !pip install autorom[accept-rom-license]
# !pip install moviepy
# !pip install numpy
# !pip install opencv-python
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.11.2)
# Collecting autorom[accept-rom-license]
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (8.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (2.32.4)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 9.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2025.11.12)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446709 sha256=26c61c7dac405f74e527a49f9633baaf373eb4283bb4ad6b343adf986dadec02
#   Stored in directory: /root/.cache/pip/wheels/99/f1/ff/c6966c034a8259164bdc9deb4d1ea839f119474638100e6645
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.6.1
# Requirement already satisfied: moviepy in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.12/dist-packages (from moviepy) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.32.4)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy) (0.1.12)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.0.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.37.2)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy) (0.6.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio<3.0,>=2.5->moviepy) (11.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2025.11.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
#@title Импорты
import gymnasium as gym
import numpy as np
import cv2
from moviepy.editor import ImageSequenceClip
import io
import base64
from IPython.display import HTML, display
import time
import os
import ale_py

gym.register_envs(ale_py)
# Out:
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:294: SyntaxWarning: invalid escape sequence '\d'
#   lines_video = [l for l in lines if ' Video: ' in l and re.search('\d+x\d+', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:367: SyntaxWarning: invalid escape sequence '\d'
#   rotation_lines = [l for l in lines if 'rotate          :' in l and re.search('\d+$', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:370: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search('\d+$', rotation_line)
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if event.key is 'enter':

# %%
#@title Константы и параметры

GAME_NAME = "ALE/MsPacman-v5"
FULL_ACTION_SPACE = False

# Random Search
N_EPISODES_RS = 500

# Hill Climbing
N_EPISODES_HC = 500
NOISE_START = 0.5        # начальный шум
NOISE_DECAY = 0.99       # уменьшение шума при неудаче
MAX_NOISE = 1.0          # максимальный шум

MAX_STEPS = 2000         # длительность эпизода
STATE_SIZE = 32          # финальное изображение 32×32 → 1024 фичи

# определение числа действий
env_tmp = gym.make(GAME_NAME, full_action_space=FULL_ACTION_SPACE)
N_ACTIONS = env_tmp.action_space.n
env_tmp.close()

FLAT_SIZE = STATE_SIZE * STATE_SIZE      # 1024
N_WEIGHTS = FLAT_SIZE * N_ACTIONS        # 1024 × actions

print("Игра:", GAME_NAME)
print("Действий:", N_ACTIONS)
print("Размер входа:", FLAT_SIZE)
print("Длина вектора весов:", N_WEIGHTS)
# Out:
# Игра: ALE/MsPacman-v5
# Действий: 9
# Размер входа: 1024
# Длина вектора весов: 9216

# %%
#@title Препроцессинг и функция выбора действия

def preprocess(state, size=STATE_SIZE):
    """Grayscale → Resize → Normalize → Flatten."""
    gray = cv2.cvtColor(state, cv2.COLOR_RGB2GRAY)
    small = cv2.resize(gray, (size, size), interpolation=cv2.INTER_AREA)
    flat = small.flatten().astype(np.float32) / 255.0
    return flat

def get_action(state, weight):
    x = preprocess(state)
    W = weight.reshape(FLAT_SIZE, N_ACTIONS)
    scores = np.dot(x, W)
    return np.argmax(scores)

# %%
#@title Запуск эпизода и функция видео

def run_episode(env, weight, max_steps=MAX_STEPS, record=False):
    state, _ = env.reset()
    total_reward = 0
    frames = []

    for t in range(max_steps):
        if record:
            frames.append(env.render())

        action = get_action(state, weight)
        state, reward, done, truncated, _ = env.step(action)

        total_reward += reward
        if done or truncated:
            break

    return total_reward, frames


def show_video(frames, filename="episode.mp4", fps=30):
    clip = ImageSequenceClip(frames, fps=fps)
    clip.write_videofile(filename, codec="libx264", audio_codec="aac", verbose=False)

    video_bytes = open(filename, "rb").read()
    encoded = base64.b64encode(video_bytes).decode()

    display(HTML(f"""
    <video width=600 controls>
        <source src="data:video/mp4;base64,{encoded}" type="video/mp4">
    </video>
    """))

# %%
#@title Random Search

env_rs = gym.make(GAME_NAME, full_action_space=FULL_ACTION_SPACE)

best_reward_rs = -1e9
best_weight_rs = None
rewards_rs = []

print("Запуск Random Search...")

for ep in range(N_EPISODES_RS):
    w = np.random.randn(N_WEIGHTS)
    reward, _ = run_episode(env_rs, w)

    rewards_rs.append(reward)

    if reward > best_reward_rs:
        best_reward_rs = reward
        best_weight_rs = w.copy()
        print(f"[НОВЫЙ ЛУЧШИЙ] Эпизод {ep+1}/{N_EPISODES_RS}: результат = {reward:.1f}")

    print(f"Эпизод {ep+1}/{N_EPISODES_RS}:\tрезультат = {reward:.1f}\tлучший результат = {best_reward_rs:.1f}")

env_rs.close()
print("Random Search завершён.")
# Out:
# Запуск Random Search...
# [НОВЫЙ ЛУЧШИЙ] Эпизод 1/500: результат = 70.0
# Эпизод 1/500:	результат = 70.0	лучший результат = 70.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 2/500: результат = 120.0
# Эпизод 2/500:	результат = 120.0	лучший результат = 120.0
# Эпизод 3/500:	результат = 70.0	лучший результат = 120.0
# Эпизод 4/500:	результат = 90.0	лучший результат = 120.0
# Эпизод 5/500:	результат = 60.0	лучший результат = 120.0
# Эпизод 6/500:	результат = 60.0	лучший результат = 120.0
# Эпизод 7/500:	результат = 70.0	лучший результат = 120.0
# Эпизод 8/500:	результат = 70.0	лучший результат = 120.0
# Эпизод 9/500:	результат = 90.0	лучший результат = 120.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 10/500: результат = 610.0
# Эпизод 10/500:	результат = 610.0	лучший результат = 610.0
# Эпизод 11/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 12/500:	результат = 220.0	лучший результат = 610.0
# Эпизод 13/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 14/500:	результат = 90.0	лучший результат = 610.0
# Эпизод 15/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 16/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 17/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 18/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 19/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 20/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 21/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 22/500:	результат = 90.0	лучший результат = 610.0
# Эпизод 23/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 24/500:	результат = 90.0	лучший результат = 610.0
# Эпизод 25/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 26/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 27/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 28/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 29/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 30/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 31/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 32/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 33/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 34/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 35/500:	результат = 90.0	лучший результат = 610.0
# Эпизод 36/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 37/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 38/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 39/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 40/500:	результат = 120.0	лучший результат = 610.0
# Эпизод 41/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 42/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 43/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 44/500:	результат = 250.0	лучший результат = 610.0
# Эпизод 45/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 46/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 47/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 48/500:	результат = 240.0	лучший результат = 610.0
# Эпизод 49/500:	результат = 120.0	лучший результат = 610.0
# Эпизод 50/500:	результат = 90.0	лучший результат = 610.0
# Эпизод 51/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 52/500:	результат = 90.0	лучший результат = 610.0
# Эпизод 53/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 54/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 55/500:	результат = 120.0	лучший результат = 610.0
# Эпизод 56/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 57/500:	результат = 240.0	лучший результат = 610.0
# Эпизод 58/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 59/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 60/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 61/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 62/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 63/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 64/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 65/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 66/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 67/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 68/500:	результат = 260.0	лучший результат = 610.0
# Эпизод 69/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 70/500:	результат = 90.0	лучший результат = 610.0
# Эпизод 71/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 72/500:	результат = 280.0	лучший результат = 610.0
# Эпизод 73/500:	результат = 290.0	лучший результат = 610.0
# Эпизод 74/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 75/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 76/500:	результат = 80.0	лучший результат = 610.0
# Эпизод 77/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 78/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 79/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 80/500:	результат = 170.0	лучший результат = 610.0
# Эпизод 81/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 82/500:	результат = 90.0	лучший результат = 610.0
# Эпизод 83/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 84/500:	результат = 570.0	лучший результат = 610.0
# Эпизод 85/500:	результат = 90.0	лучший результат = 610.0
# Эпизод 86/500:	результат = 60.0	лучший результат = 610.0
# Эпизод 87/500:	результат = 70.0	лучший результат = 610.0
# Эпизод 88/500:	результат = 90.0	лучший результат = 610.0
# Эпизод 89/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 90/500:	результат = 270.0	лучший результат = 610.0
# Эпизод 91/500:	результат = 210.0	лучший результат = 610.0
# Эпизод 92/500:	результат = 60.0	лучший результат = 610.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 93/500: результат = 1210.0
# Эпизод 93/500:	результат = 1210.0	лучший результат = 1210.0
# Эпизод 94/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 95/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 96/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 97/500:	результат = 100.0	лучший результат = 1210.0
# Эпизод 98/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 99/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 100/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 101/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 102/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 103/500:	результат = 390.0	лучший результат = 1210.0
# Эпизод 104/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 105/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 106/500:	результат = 200.0	лучший результат = 1210.0
# Эпизод 107/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 108/500:	результат = 220.0	лучший результат = 1210.0
# Эпизод 109/500:	результат = 120.0	лучший результат = 1210.0
# Эпизод 110/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 111/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 112/500:	результат = 410.0	лучший результат = 1210.0
# Эпизод 113/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 114/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 115/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 116/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 117/500:	результат = 180.0	лучший результат = 1210.0
# Эпизод 118/500:	результат = 130.0	лучший результат = 1210.0
# Эпизод 119/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 120/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 121/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 122/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 123/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 124/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 125/500:	результат = 130.0	лучший результат = 1210.0
# Эпизод 126/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 127/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 128/500:	результат = 250.0	лучший результат = 1210.0
# Эпизод 129/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 130/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 131/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 132/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 133/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 134/500:	результат = 460.0	лучший результат = 1210.0
# Эпизод 135/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 136/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 137/500:	результат = 160.0	лучший результат = 1210.0
# Эпизод 138/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 139/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 140/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 141/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 142/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 143/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 144/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 145/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 146/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 147/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 148/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 149/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 150/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 151/500:	результат = 190.0	лучший результат = 1210.0
# Эпизод 152/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 153/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 154/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 155/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 156/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 157/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 158/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 159/500:	результат = 450.0	лучший результат = 1210.0
# Эпизод 160/500:	результат = 250.0	лучший результат = 1210.0
# Эпизод 161/500:	результат = 360.0	лучший результат = 1210.0
# Эпизод 162/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 163/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 164/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 165/500:	результат = 110.0	лучший результат = 1210.0
# Эпизод 166/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 167/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 168/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 169/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 170/500:	результат = 310.0	лучший результат = 1210.0
# Эпизод 171/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 172/500:	результат = 210.0	лучший результат = 1210.0
# Эпизод 173/500:	результат = 120.0	лучший результат = 1210.0
# Эпизод 174/500:	результат = 70.0	лучший результат = 1210.0
# Эпизод 175/500:	результат = 190.0	лучший результат = 1210.0
# Эпизод 176/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 177/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 178/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 179/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 180/500:	результат = 60.0	лучший результат = 1210.0
# Эпизод 181/500:	результат = 90.0	лучший результат = 1210.0
# Эпизод 182/500:	результат = 170.0	лучший результат = 1210.0
# Эпизод 183/500:	результат = 210.0	лучший результат = 1210.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 184/500: результат = 1710.0
# Эпизод 184/500:	результат = 1710.0	лучший результат = 1710.0
# Эпизод 185/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 186/500:	результат = 290.0	лучший результат = 1710.0
# Эпизод 187/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 188/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 189/500:	результат = 90.0	лучший результат = 1710.0
# Эпизод 190/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 191/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 192/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 193/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 194/500:	результат = 600.0	лучший результат = 1710.0
# Эпизод 195/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 196/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 197/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 198/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 199/500:	результат = 130.0	лучший результат = 1710.0
# Эпизод 200/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 201/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 202/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 203/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 204/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 205/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 206/500:	результат = 290.0	лучший результат = 1710.0
# Эпизод 207/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 208/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 209/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 210/500:	результат = 160.0	лучший результат = 1710.0
# Эпизод 211/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 212/500:	результат = 170.0	лучший результат = 1710.0
# Эпизод 213/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 214/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 215/500:	результат = 280.0	лучший результат = 1710.0
# Эпизод 216/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 217/500:	результат = 170.0	лучший результат = 1710.0
# Эпизод 218/500:	результат = 90.0	лучший результат = 1710.0
# Эпизод 219/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 220/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 221/500:	результат = 140.0	лучший результат = 1710.0
# Эпизод 222/500:	результат = 100.0	лучший результат = 1710.0
# Эпизод 223/500:	результат = 110.0	лучший результат = 1710.0
# Эпизод 224/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 225/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 226/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 227/500:	результат = 90.0	лучший результат = 1710.0
# Эпизод 228/500:	результат = 80.0	лучший результат = 1710.0
# Эпизод 229/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 230/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 231/500:	результат = 110.0	лучший результат = 1710.0
# Эпизод 232/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 233/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 234/500:	результат = 280.0	лучший результат = 1710.0
# Эпизод 235/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 236/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 237/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 238/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 239/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 240/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 241/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 242/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 243/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 244/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 245/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 246/500:	результат = 170.0	лучший результат = 1710.0
# Эпизод 247/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 248/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 249/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 250/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 251/500:	результат = 270.0	лучший результат = 1710.0
# Эпизод 252/500:	результат = 170.0	лучший результат = 1710.0
# Эпизод 253/500:	результат = 290.0	лучший результат = 1710.0
# Эпизод 254/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 255/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 256/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 257/500:	результат = 110.0	лучший результат = 1710.0
# Эпизод 258/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 259/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 260/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 261/500:	результат = 60.0	лучший результат = 1710.0
# Эпизод 262/500:	результат = 180.0	лучший результат = 1710.0
# Эпизод 263/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 264/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 265/500:	результат = 320.0	лучший результат = 1710.0
# Эпизод 266/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 267/500:	результат = 210.0	лучший результат = 1710.0
# Эпизод 268/500:	результат = 70.0	лучший результат = 1710.0
# Эпизод 269/500:	результат = 60.0	лучший результат = 1710.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 270/500: результат = 1730.0
# Эпизод 270/500:	результат = 1730.0	лучший результат = 1730.0
# Эпизод 271/500:	результат = 320.0	лучший результат = 1730.0
# Эпизод 272/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 273/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 274/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 275/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 276/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 277/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 278/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 279/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 280/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 281/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 282/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 283/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 284/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 285/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 286/500:	результат = 140.0	лучший результат = 1730.0
# Эпизод 287/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 288/500:	результат = 230.0	лучший результат = 1730.0
# Эпизод 289/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 290/500:	результат = 440.0	лучший результат = 1730.0
# Эпизод 291/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 292/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 293/500:	результат = 310.0	лучший результат = 1730.0
# Эпизод 294/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 295/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 296/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 297/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 298/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 299/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 300/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 301/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 302/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 303/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 304/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 305/500:	результат = 410.0	лучший результат = 1730.0
# Эпизод 306/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 307/500:	результат = 320.0	лучший результат = 1730.0
# Эпизод 308/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 309/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 310/500:	результат = 410.0	лучший результат = 1730.0
# Эпизод 311/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 312/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 313/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 314/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 315/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 316/500:	результат = 320.0	лучший результат = 1730.0
# Эпизод 317/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 318/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 319/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 320/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 321/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 322/500:	результат = 150.0	лучший результат = 1730.0
# Эпизод 323/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 324/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 325/500:	результат = 130.0	лучший результат = 1730.0
# Эпизод 326/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 327/500:	результат = 260.0	лучший результат = 1730.0
# Эпизод 328/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 329/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 330/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 331/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 332/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 333/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 334/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 335/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 336/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 337/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 338/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 339/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 340/500:	результат = 220.0	лучший результат = 1730.0
# Эпизод 341/500:	результат = 420.0	лучший результат = 1730.0
# Эпизод 342/500:	результат = 250.0	лучший результат = 1730.0
# Эпизод 343/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 344/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 345/500:	результат = 250.0	лучший результат = 1730.0
# Эпизод 346/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 347/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 348/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 349/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 350/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 351/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 352/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 353/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 354/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 355/500:	результат = 160.0	лучший результат = 1730.0
# Эпизод 356/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 357/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 358/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 359/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 360/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 361/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 362/500:	результат = 440.0	лучший результат = 1730.0
# Эпизод 363/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 364/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 365/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 366/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 367/500:	результат = 140.0	лучший результат = 1730.0
# Эпизод 368/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 369/500:	результат = 390.0	лучший результат = 1730.0
# Эпизод 370/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 371/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 372/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 373/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 374/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 375/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 376/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 377/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 378/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 379/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 380/500:	результат = 200.0	лучший результат = 1730.0
# Эпизод 381/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 382/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 383/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 384/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 385/500:	результат = 320.0	лучший результат = 1730.0
# Эпизод 386/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 387/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 388/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 389/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 390/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 391/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 392/500:	результат = 290.0	лучший результат = 1730.0
# Эпизод 393/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 394/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 395/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 396/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 397/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 398/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 399/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 400/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 401/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 402/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 403/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 404/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 405/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 406/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 407/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 408/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 409/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 410/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 411/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 412/500:	результат = 80.0	лучший результат = 1730.0
# Эпизод 413/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 414/500:	результат = 220.0	лучший результат = 1730.0
# Эпизод 415/500:	результат = 170.0	лучший результат = 1730.0
# Эпизод 416/500:	результат = 110.0	лучший результат = 1730.0
# Эпизод 417/500:	результат = 240.0	лучший результат = 1730.0
# Эпизод 418/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 419/500:	результат = 630.0	лучший результат = 1730.0
# Эпизод 420/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 421/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 422/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 423/500:	результат = 290.0	лучший результат = 1730.0
# Эпизод 424/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 425/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 426/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 427/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 428/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 429/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 430/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 431/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 432/500:	результат = 220.0	лучший результат = 1730.0
# Эпизод 433/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 434/500:	результат = 220.0	лучший результат = 1730.0
# Эпизод 435/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 436/500:	результат = 220.0	лучший результат = 1730.0
# Эпизод 437/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 438/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 439/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 440/500:	результат = 120.0	лучший результат = 1730.0
# Эпизод 441/500:	результат = 390.0	лучший результат = 1730.0
# Эпизод 442/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 443/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 444/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 445/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 446/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 447/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 448/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 449/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 450/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 451/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 452/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 453/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 454/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 455/500:	результат = 450.0	лучший результат = 1730.0
# Эпизод 456/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 457/500:	результат = 320.0	лучший результат = 1730.0
# Эпизод 458/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 459/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 460/500:	результат = 290.0	лучший результат = 1730.0
# Эпизод 461/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 462/500:	результат = 120.0	лучший результат = 1730.0
# Эпизод 463/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 464/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 465/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 466/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 467/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 468/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 469/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 470/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 471/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 472/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 473/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 474/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 475/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 476/500:	результат = 120.0	лучший результат = 1730.0
# Эпизод 477/500:	результат = 170.0	лучший результат = 1730.0
# Эпизод 478/500:	результат = 930.0	лучший результат = 1730.0
# Эпизод 479/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 480/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 481/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 482/500:	результат = 140.0	лучший результат = 1730.0
# Эпизод 483/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 484/500:	результат = 450.0	лучший результат = 1730.0
# Эпизод 485/500:	результат = 150.0	лучший результат = 1730.0
# Эпизод 486/500:	результат = 250.0	лучший результат = 1730.0
# Эпизод 487/500:	результат = 120.0	лучший результат = 1730.0
# Эпизод 488/500:	результат = 240.0	лучший результат = 1730.0
# Эпизод 489/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 490/500:	результат = 140.0	лучший результат = 1730.0
# Эпизод 491/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 492/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 493/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 494/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 495/500:	результат = 90.0	лучший результат = 1730.0
# Эпизод 496/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 497/500:	результат = 70.0	лучший результат = 1730.0
# Эпизод 498/500:	результат = 210.0	лучший результат = 1730.0
# Эпизод 499/500:	результат = 60.0	лучший результат = 1730.0
# Эпизод 500/500:	результат = 60.0	лучший результат = 1730.0
# Random Search завершён.

# %%
#@title Видео результата Random Search

print("Лучший reward Random Search, достигнутый в тренировке:", best_reward_rs)

# Запуск лучшего веса несколько раз для видео, чтобы
# нивелировать стохастичность и показать максимальный результат.
N_EVAL_RUNS = 5
best_eval_reward_rs = -1e9
best_eval_frames_rs = []

env_render_rs = gym.make(GAME_NAME, full_action_space=FULL_ACTION_SPACE, render_mode="rgb_array")

print(f"Проверка лучшего веса на {N_EVAL_RUNS} эпизодах для записи лучшего видео Random Search...")

for i in range(N_EVAL_RUNS):
    # Используем best_weight_rs, найденный в Random Search
    reward, frames = run_episode(env_render_rs, best_weight_rs, record=True)
    print(f"Оценочный прогон {i+1}: reward = {reward:.1f}")

    if reward > best_eval_reward_rs:
        best_eval_reward_rs = reward
        best_eval_frames_rs = frames

env_render_rs.close()

print(f"Максимальный reward для видео Random Search: {best_eval_reward_rs:.1f}")

show_video(best_eval_frames_rs, "best_random_search.mp4")
# Out:
# Лучший reward Random Search, достигнутый в тренировке: 1730.0
# Проверка лучшего веса на 5 эпизодах для записи лучшего видео Random Search...
# Оценочный прогон 1: reward = 1740.0
# Оценочный прогон 2: reward = 1800.0
# Оценочный прогон 3: reward = 1770.0
# Оценочный прогон 4: reward = 1800.0
# Оценочный прогон 5: reward = 1710.0
# Максимальный reward для видео Random Search: 1800.0
# Moviepy - Building video best_random_search.mp4.
# Moviepy - Writing video best_random_search.mp4
# Moviepy - Done !
# Moviepy - video ready best_random_search.mp4
#     <video width=600 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
#@title Hill Climbing

env_hc = gym.make(GAME_NAME, full_action_space=FULL_ACTION_SPACE)

NOISE = NOISE_START
w_best = np.random.randn(N_WEIGHTS)

r_best, _ = run_episode(env_hc, w_best)

print("Старт Hill Climbing. Стартовое вознаграждение:", r_best)

rewards_hc = []

for ep in range(N_EPISODES_HC):

    w_try = w_best + NOISE * np.random.randn(N_WEIGHTS)
    reward, _ = run_episode(env_hc, w_try)
    rewards_hc.append(reward)

    if reward >= r_best:
        r_best = reward
        w_best = w_try.copy()
        NOISE = min(NOISE * 1.05, MAX_NOISE)
        print(f"[НОВЫЙ ЛУЧШИЙ] Эпизод {ep+1}/{N_EPISODES_HC}: результат = {reward:.1f}, шум = {NOISE:.3f}")
    else:
        NOISE *= NOISE_DECAY

    print(f"Эпизод {ep+1}:\tрезультат = {reward:.1f}\tшум = {NOISE:.3f}\t лучший результат = {r_best:.1f}")

env_hc.close()
print("Hill Climbing завершён. Лучший результат:", r_best)
# Out:
# Старт Hill Climbing. Стартовое вознаграждение: 270.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 1/500: результат = 360.0, шум = 0.525
# Эпизод 1:	результат = 360.0	шум = 0.525	 лучший результат = 360.0
# Эпизод 2:	результат = 210.0	шум = 0.520	 лучший результат = 360.0
# Эпизод 3:	результат = 210.0	шум = 0.515	 лучший результат = 360.0
# Эпизод 4:	результат = 70.0	шум = 0.509	 лучший результат = 360.0
# Эпизод 5:	результат = 140.0	шум = 0.504	 лучший результат = 360.0
# Эпизод 6:	результат = 210.0	шум = 0.499	 лучший результат = 360.0
# Эпизод 7:	результат = 70.0	шум = 0.494	 лучший результат = 360.0
# Эпизод 8:	результат = 70.0	шум = 0.489	 лучший результат = 360.0
# Эпизод 9:	результат = 70.0	шум = 0.484	 лучший результат = 360.0
# Эпизод 10:	результат = 70.0	шум = 0.480	 лучший результат = 360.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 11/500: результат = 380.0, шум = 0.504
# Эпизод 11:	результат = 380.0	шум = 0.504	 лучший результат = 380.0
# Эпизод 12:	результат = 320.0	шум = 0.499	 лучший результат = 380.0
# Эпизод 13:	результат = 320.0	шум = 0.494	 лучший результат = 380.0
# Эпизод 14:	результат = 210.0	шум = 0.489	 лучший результат = 380.0
# Эпизод 15:	результат = 320.0	шум = 0.484	 лучший результат = 380.0
# Эпизод 16:	результат = 270.0	шум = 0.479	 лучший результат = 380.0
# Эпизод 17:	результат = 210.0	шум = 0.474	 лучший результат = 380.0
# Эпизод 18:	результат = 210.0	шум = 0.469	 лучший результат = 380.0
# Эпизод 19:	результат = 70.0	шум = 0.465	 лучший результат = 380.0
# Эпизод 20:	результат = 260.0	шум = 0.460	 лучший результат = 380.0
# Эпизод 21:	результат = 70.0	шум = 0.455	 лучший результат = 380.0
# Эпизод 22:	результат = 210.0	шум = 0.451	 лучший результат = 380.0
# Эпизод 23:	результат = 70.0	шум = 0.446	 лучший результат = 380.0
# Эпизод 24:	результат = 70.0	шум = 0.442	 лучший результат = 380.0
# Эпизод 25:	результат = 140.0	шум = 0.437	 лучший результат = 380.0
# Эпизод 26:	результат = 190.0	шум = 0.433	 лучший результат = 380.0
# Эпизод 27:	результат = 210.0	шум = 0.429	 лучший результат = 380.0
# Эпизод 28:	результат = 210.0	шум = 0.424	 лучший результат = 380.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 29/500: результат = 410.0, шум = 0.446
# Эпизод 29:	результат = 410.0	шум = 0.446	 лучший результат = 410.0
# Эпизод 30:	результат = 80.0	шум = 0.441	 лучший результат = 410.0
# Эпизод 31:	результат = 240.0	шум = 0.437	 лучший результат = 410.0
# Эпизод 32:	результат = 70.0	шум = 0.432	 лучший результат = 410.0
# Эпизод 33:	результат = 210.0	шум = 0.428	 лучший результат = 410.0
# Эпизод 34:	результат = 320.0	шум = 0.424	 лучший результат = 410.0
# Эпизод 35:	результат = 240.0	шум = 0.420	 лучший результат = 410.0
# Эпизод 36:	результат = 190.0	шум = 0.415	 лучший результат = 410.0
# Эпизод 37:	результат = 60.0	шум = 0.411	 лучший результат = 410.0
# Эпизод 38:	результат = 60.0	шум = 0.407	 лучший результат = 410.0
# Эпизод 39:	результат = 60.0	шум = 0.403	 лучший результат = 410.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 40/500: результат = 1970.0, шум = 0.423
# Эпизод 40:	результат = 1970.0	шум = 0.423	 лучший результат = 1970.0
# Эпизод 41:	результат = 60.0	шум = 0.419	 лучший результат = 1970.0
# Эпизод 42:	результат = 60.0	шум = 0.415	 лучший результат = 1970.0
# Эпизод 43:	результат = 60.0	шум = 0.411	 лучший результат = 1970.0
# Эпизод 44:	результат = 360.0	шум = 0.407	 лучший результат = 1970.0
# Эпизод 45:	результат = 140.0	шум = 0.403	 лучший результат = 1970.0
# Эпизод 46:	результат = 350.0	шум = 0.398	 лучший результат = 1970.0
# Эпизод 47:	результат = 60.0	шум = 0.394	 лучший результат = 1970.0
# Эпизод 48:	результат = 70.0	шум = 0.391	 лучший результат = 1970.0
# Эпизод 49:	результат = 410.0	шум = 0.387	 лучший результат = 1970.0
# Эпизод 50:	результат = 240.0	шум = 0.383	 лучший результат = 1970.0
# Эпизод 51:	результат = 440.0	шум = 0.379	 лучший результат = 1970.0
# Эпизод 52:	результат = 60.0	шум = 0.375	 лучший результат = 1970.0
# Эпизод 53:	результат = 140.0	шум = 0.371	 лучший результат = 1970.0
# Эпизод 54:	результат = 380.0	шум = 0.368	 лучший результат = 1970.0
# Эпизод 55:	результат = 180.0	шум = 0.364	 лучший результат = 1970.0
# Эпизод 56:	результат = 240.0	шум = 0.360	 лучший результат = 1970.0
# Эпизод 57:	результат = 930.0	шум = 0.357	 лучший результат = 1970.0
# Эпизод 58:	результат = 60.0	шум = 0.353	 лучший результат = 1970.0
# Эпизод 59:	результат = 70.0	шум = 0.350	 лучший результат = 1970.0
# Эпизод 60:	результат = 200.0	шум = 0.346	 лучший результат = 1970.0
# Эпизод 61:	результат = 340.0	шум = 0.343	 лучший результат = 1970.0
# Эпизод 62:	результат = 60.0	шум = 0.339	 лучший результат = 1970.0
# Эпизод 63:	результат = 600.0	шум = 0.336	 лучший результат = 1970.0
# Эпизод 64:	результат = 190.0	шум = 0.333	 лучший результат = 1970.0
# Эпизод 65:	результат = 60.0	шум = 0.329	 лучший результат = 1970.0
# Эпизод 66:	результат = 90.0	шум = 0.326	 лучший результат = 1970.0
# Эпизод 67:	результат = 290.0	шум = 0.323	 лучший результат = 1970.0
# Эпизод 68:	результат = 210.0	шум = 0.319	 лучший результат = 1970.0
# Эпизод 69:	результат = 270.0	шум = 0.316	 лучший результат = 1970.0
# Эпизод 70:	результат = 320.0	шум = 0.313	 лучший результат = 1970.0
# Эпизод 71:	результат = 60.0	шум = 0.310	 лучший результат = 1970.0
# Эпизод 72:	результат = 520.0	шум = 0.307	 лучший результат = 1970.0
# Эпизод 73:	результат = 140.0	шум = 0.304	 лучший результат = 1970.0
# Эпизод 74:	результат = 90.0	шум = 0.301	 лучший результат = 1970.0
# Эпизод 75:	результат = 70.0	шум = 0.298	 лучший результат = 1970.0
# Эпизод 76:	результат = 70.0	шум = 0.295	 лучший результат = 1970.0
# Эпизод 77:	результат = 210.0	шум = 0.292	 лучший результат = 1970.0
# Эпизод 78:	результат = 60.0	шум = 0.289	 лучший результат = 1970.0
# Эпизод 79:	результат = 170.0	шум = 0.286	 лучший результат = 1970.0
# Эпизод 80:	результат = 60.0	шум = 0.283	 лучший результат = 1970.0
# Эпизод 81:	результат = 390.0	шум = 0.280	 лучший результат = 1970.0
# Эпизод 82:	результат = 70.0	шум = 0.278	 лучший результат = 1970.0
# Эпизод 83:	результат = 140.0	шум = 0.275	 лучший результат = 1970.0
# Эпизод 84:	результат = 240.0	шум = 0.272	 лучший результат = 1970.0
# Эпизод 85:	результат = 210.0	шум = 0.269	 лучший результат = 1970.0
# Эпизод 86:	результат = 440.0	шум = 0.267	 лучший результат = 1970.0
# Эпизод 87:	результат = 320.0	шум = 0.264	 лучший результат = 1970.0
# Эпизод 88:	результат = 210.0	шум = 0.261	 лучший результат = 1970.0
# Эпизод 89:	результат = 70.0	шум = 0.259	 лучший результат = 1970.0
# Эпизод 90:	результат = 330.0	шум = 0.256	 лучший результат = 1970.0
# Эпизод 91:	результат = 70.0	шум = 0.254	 лучший результат = 1970.0
# Эпизод 92:	результат = 70.0	шум = 0.251	 лучший результат = 1970.0
# Эпизод 93:	результат = 200.0	шум = 0.248	 лучший результат = 1970.0
# Эпизод 94:	результат = 210.0	шум = 0.246	 лучший результат = 1970.0
# Эпизод 95:	результат = 330.0	шум = 0.244	 лучший результат = 1970.0
# Эпизод 96:	результат = 380.0	шум = 0.241	 лучший результат = 1970.0
# Эпизод 97:	результат = 460.0	шум = 0.239	 лучший результат = 1970.0
# Эпизод 98:	результат = 350.0	шум = 0.236	 лучший результат = 1970.0
# Эпизод 99:	результат = 60.0	шум = 0.234	 лучший результат = 1970.0
# Эпизод 100:	результат = 330.0	шум = 0.232	 лучший результат = 1970.0
# Эпизод 101:	результат = 240.0	шум = 0.229	 лучший результат = 1970.0
# Эпизод 102:	результат = 210.0	шум = 0.227	 лучший результат = 1970.0
# Эпизод 103:	результат = 320.0	шум = 0.225	 лучший результат = 1970.0
# Эпизод 104:	результат = 320.0	шум = 0.222	 лучший результат = 1970.0
# Эпизод 105:	результат = 320.0	шум = 0.220	 лучший результат = 1970.0
# Эпизод 106:	результат = 280.0	шум = 0.218	 лучший результат = 1970.0
# Эпизод 107:	результат = 320.0	шум = 0.216	 лучший результат = 1970.0
# Эпизод 108:	результат = 60.0	шум = 0.214	 лучший результат = 1970.0
# Эпизод 109:	результат = 360.0	шум = 0.212	 лучший результат = 1970.0
# Эпизод 110:	результат = 990.0	шум = 0.209	 лучший результат = 1970.0
# Эпизод 111:	результат = 330.0	шум = 0.207	 лучший результат = 1970.0
# Эпизод 112:	результат = 240.0	шум = 0.205	 лучший результат = 1970.0
# Эпизод 113:	результат = 60.0	шум = 0.203	 лучший результат = 1970.0
# Эпизод 114:	результат = 590.0	шум = 0.201	 лучший результат = 1970.0
# Эпизод 115:	результат = 500.0	шум = 0.199	 лучший результат = 1970.0
# Эпизод 116:	результат = 330.0	шум = 0.197	 лучший результат = 1970.0
# Эпизод 117:	результат = 240.0	шум = 0.195	 лучший результат = 1970.0
# Эпизод 118:	результат = 70.0	шум = 0.193	 лучший результат = 1970.0
# Эпизод 119:	результат = 140.0	шум = 0.191	 лучший результат = 1970.0
# Эпизод 120:	результат = 190.0	шум = 0.189	 лучший результат = 1970.0
# Эпизод 121:	результат = 280.0	шум = 0.188	 лучший результат = 1970.0
# Эпизод 122:	результат = 240.0	шум = 0.186	 лучший результат = 1970.0
# Эпизод 123:	результат = 470.0	шум = 0.184	 лучший результат = 1970.0
# Эпизод 124:	результат = 200.0	шум = 0.182	 лучший результат = 1970.0
# Эпизод 125:	результат = 330.0	шум = 0.180	 лучший результат = 1970.0
# Эпизод 126:	результат = 260.0	шум = 0.178	 лучший результат = 1970.0
# Эпизод 127:	результат = 320.0	шум = 0.177	 лучший результат = 1970.0
# Эпизод 128:	результат = 70.0	шум = 0.175	 лучший результат = 1970.0
# Эпизод 129:	результат = 330.0	шум = 0.173	 лучший результат = 1970.0
# Эпизод 130:	результат = 540.0	шум = 0.171	 лучший результат = 1970.0
# Эпизод 131:	результат = 250.0	шум = 0.170	 лучший результат = 1970.0
# Эпизод 132:	результат = 210.0	шум = 0.168	 лучший результат = 1970.0
# Эпизод 133:	результат = 130.0	шум = 0.166	 лучший результат = 1970.0
# Эпизод 134:	результат = 60.0	шум = 0.165	 лучший результат = 1970.0
# Эпизод 135:	результат = 570.0	шум = 0.163	 лучший результат = 1970.0
# Эпизод 136:	результат = 440.0	шум = 0.161	 лучший результат = 1970.0
# Эпизод 137:	результат = 240.0	шум = 0.160	 лучший результат = 1970.0
# Эпизод 138:	результат = 320.0	шум = 0.158	 лучший результат = 1970.0
# Эпизод 139:	результат = 110.0	шум = 0.156	 лучший результат = 1970.0
# Эпизод 140:	результат = 320.0	шум = 0.155	 лучший результат = 1970.0
# Эпизод 141:	результат = 330.0	шум = 0.153	 лучший результат = 1970.0
# Эпизод 142:	результат = 330.0	шум = 0.152	 лучший результат = 1970.0
# Эпизод 143:	результат = 240.0	шум = 0.150	 лучший результат = 1970.0
# Эпизод 144:	результат = 430.0	шум = 0.149	 лучший результат = 1970.0
# Эпизод 145:	результат = 450.0	шум = 0.147	 лучший результат = 1970.0
# Эпизод 146:	результат = 370.0	шум = 0.146	 лучший результат = 1970.0
# Эпизод 147:	результат = 190.0	шум = 0.144	 лучший результат = 1970.0
# Эпизод 148:	результат = 240.0	шум = 0.143	 лучший результат = 1970.0
# Эпизод 149:	результат = 380.0	шум = 0.142	 лучший результат = 1970.0
# Эпизод 150:	результат = 330.0	шум = 0.140	 лучший результат = 1970.0
# Эпизод 151:	результат = 430.0	шум = 0.139	 лучший результат = 1970.0
# Эпизод 152:	результат = 380.0	шум = 0.137	 лучший результат = 1970.0
# Эпизод 153:	результат = 140.0	шум = 0.136	 лучший результат = 1970.0
# Эпизод 154:	результат = 360.0	шум = 0.135	 лучший результат = 1970.0
# Эпизод 155:	результат = 330.0	шум = 0.133	 лучший результат = 1970.0
# Эпизод 156:	результат = 210.0	шум = 0.132	 лучший результат = 1970.0
# Эпизод 157:	результат = 590.0	шум = 0.131	 лучший результат = 1970.0
# Эпизод 158:	результат = 190.0	шум = 0.129	 лучший результат = 1970.0
# Эпизод 159:	результат = 300.0	шум = 0.128	 лучший результат = 1970.0
# Эпизод 160:	результат = 370.0	шум = 0.127	 лучший результат = 1970.0
# Эпизод 161:	результат = 60.0	шум = 0.125	 лучший результат = 1970.0
# Эпизод 162:	результат = 330.0	шум = 0.124	 лучший результат = 1970.0
# Эпизод 163:	результат = 190.0	шум = 0.123	 лучший результат = 1970.0
# Эпизод 164:	результат = 470.0	шум = 0.122	 лучший результат = 1970.0
# Эпизод 165:	результат = 450.0	шум = 0.121	 лучший результат = 1970.0
# Эпизод 166:	результат = 520.0	шум = 0.119	 лучший результат = 1970.0
# Эпизод 167:	результат = 210.0	шум = 0.118	 лучший результат = 1970.0
# Эпизод 168:	результат = 280.0	шум = 0.117	 лучший результат = 1970.0
# Эпизод 169:	результат = 350.0	шум = 0.116	 лучший результат = 1970.0
# Эпизод 170:	результат = 60.0	шум = 0.115	 лучший результат = 1970.0
# Эпизод 171:	результат = 520.0	шум = 0.113	 лучший результат = 1970.0
# Эпизод 172:	результат = 280.0	шум = 0.112	 лучший результат = 1970.0
# Эпизод 173:	результат = 400.0	шум = 0.111	 лучший результат = 1970.0
# Эпизод 174:	результат = 330.0	шум = 0.110	 лучший результат = 1970.0
# Эпизод 175:	результат = 1320.0	шум = 0.109	 лучший результат = 1970.0
# Эпизод 176:	результат = 320.0	шум = 0.108	 лучший результат = 1970.0
# Эпизод 177:	результат = 410.0	шум = 0.107	 лучший результат = 1970.0
# Эпизод 178:	результат = 540.0	шум = 0.106	 лучший результат = 1970.0
# Эпизод 179:	результат = 240.0	шум = 0.105	 лучший результат = 1970.0
# Эпизод 180:	результат = 190.0	шум = 0.104	 лучший результат = 1970.0
# Эпизод 181:	результат = 650.0	шум = 0.103	 лучший результат = 1970.0
# Эпизод 182:	результат = 110.0	шум = 0.102	 лучший результат = 1970.0
# Эпизод 183:	результат = 650.0	шум = 0.101	 лучший результат = 1970.0
# Эпизод 184:	результат = 350.0	шум = 0.100	 лучший результат = 1970.0
# Эпизод 185:	результат = 580.0	шум = 0.099	 лучший результат = 1970.0
# Эпизод 186:	результат = 440.0	шум = 0.098	 лучший результат = 1970.0
# Эпизод 187:	результат = 320.0	шум = 0.097	 лучший результат = 1970.0
# Эпизод 188:	результат = 290.0	шум = 0.096	 лучший результат = 1970.0
# Эпизод 189:	результат = 260.0	шум = 0.095	 лучший результат = 1970.0
# Эпизод 190:	результат = 470.0	шум = 0.094	 лучший результат = 1970.0
# Эпизод 191:	результат = 510.0	шум = 0.093	 лучший результат = 1970.0
# Эпизод 192:	результат = 290.0	шум = 0.092	 лучший результат = 1970.0
# Эпизод 193:	результат = 690.0	шум = 0.091	 лучший результат = 1970.0
# Эпизод 194:	результат = 440.0	шум = 0.090	 лучший результат = 1970.0
# Эпизод 195:	результат = 460.0	шум = 0.089	 лучший результат = 1970.0
# Эпизод 196:	результат = 310.0	шум = 0.088	 лучший результат = 1970.0
# Эпизод 197:	результат = 400.0	шум = 0.087	 лучший результат = 1970.0
# Эпизод 198:	результат = 190.0	шум = 0.086	 лучший результат = 1970.0
# Эпизод 199:	результат = 420.0	шум = 0.086	 лучший результат = 1970.0
# Эпизод 200:	результат = 430.0	шум = 0.085	 лучший результат = 1970.0
# Эпизод 201:	результат = 350.0	шум = 0.084	 лучший результат = 1970.0
# Эпизод 202:	результат = 640.0	шум = 0.083	 лучший результат = 1970.0
# Эпизод 203:	результат = 350.0	шум = 0.082	 лучший результат = 1970.0
# Эпизод 204:	результат = 720.0	шум = 0.081	 лучший результат = 1970.0
# Эпизод 205:	результат = 550.0	шум = 0.081	 лучший результат = 1970.0
# Эпизод 206:	результат = 280.0	шум = 0.080	 лучший результат = 1970.0
# Эпизод 207:	результат = 690.0	шум = 0.079	 лучший результат = 1970.0
# Эпизод 208:	результат = 320.0	шум = 0.078	 лучший результат = 1970.0
# Эпизод 209:	результат = 1880.0	шум = 0.077	 лучший результат = 1970.0
# Эпизод 210:	результат = 490.0	шум = 0.077	 лучший результат = 1970.0
# Эпизод 211:	результат = 620.0	шум = 0.076	 лучший результат = 1970.0
# Эпизод 212:	результат = 310.0	шум = 0.075	 лучший результат = 1970.0
# Эпизод 213:	результат = 390.0	шум = 0.074	 лучший результат = 1970.0
# Эпизод 214:	результат = 240.0	шум = 0.074	 лучший результат = 1970.0
# Эпизод 215:	результат = 250.0	шум = 0.073	 лучший результат = 1970.0
# Эпизод 216:	результат = 430.0	шум = 0.072	 лучший результат = 1970.0
# Эпизод 217:	результат = 310.0	шум = 0.071	 лучший результат = 1970.0
# Эпизод 218:	результат = 420.0	шум = 0.071	 лучший результат = 1970.0
# Эпизод 219:	результат = 320.0	шум = 0.070	 лучший результат = 1970.0
# Эпизод 220:	результат = 650.0	шум = 0.069	 лучший результат = 1970.0
# Эпизод 221:	результат = 290.0	шум = 0.069	 лучший результат = 1970.0
# Эпизод 222:	результат = 320.0	шум = 0.068	 лучший результат = 1970.0
# Эпизод 223:	результат = 290.0	шум = 0.067	 лучший результат = 1970.0
# Эпизод 224:	результат = 190.0	шум = 0.067	 лучший результат = 1970.0
# Эпизод 225:	результат = 930.0	шум = 0.066	 лучший результат = 1970.0
# Эпизод 226:	результат = 330.0	шум = 0.065	 лучший результат = 1970.0
# Эпизод 227:	результат = 430.0	шум = 0.065	 лучший результат = 1970.0
# Эпизод 228:	результат = 350.0	шум = 0.064	 лучший результат = 1970.0
# Эпизод 229:	результат = 580.0	шум = 0.063	 лучший результат = 1970.0
# Эпизод 230:	результат = 930.0	шум = 0.063	 лучший результат = 1970.0
# Эпизод 231:	результат = 310.0	шум = 0.062	 лучший результат = 1970.0
# Эпизод 232:	результат = 400.0	шум = 0.061	 лучший результат = 1970.0
# Эпизод 233:	результат = 290.0	шум = 0.061	 лучший результат = 1970.0
# Эпизод 234:	результат = 240.0	шум = 0.060	 лучший результат = 1970.0
# Эпизод 235:	результат = 920.0	шум = 0.060	 лучший результат = 1970.0
# Эпизод 236:	результат = 190.0	шум = 0.059	 лучший результат = 1970.0
# Эпизод 237:	результат = 650.0	шум = 0.058	 лучший результат = 1970.0
# Эпизод 238:	результат = 270.0	шум = 0.058	 лучший результат = 1970.0
# Эпизод 239:	результат = 360.0	шум = 0.057	 лучший результат = 1970.0
# Эпизод 240:	результат = 1190.0	шум = 0.057	 лучший результат = 1970.0
# Эпизод 241:	результат = 380.0	шум = 0.056	 лучший результат = 1970.0
# Эпизод 242:	результат = 390.0	шум = 0.056	 лучший результат = 1970.0
# Эпизод 243:	результат = 330.0	шум = 0.055	 лучший результат = 1970.0
# Эпизод 244:	результат = 1900.0	шум = 0.054	 лучший результат = 1970.0
# Эпизод 245:	результат = 420.0	шум = 0.054	 лучший результат = 1970.0
# Эпизод 246:	результат = 450.0	шум = 0.053	 лучший результат = 1970.0
# Эпизод 247:	результат = 440.0	шум = 0.053	 лучший результат = 1970.0
# Эпизод 248:	результат = 330.0	шум = 0.052	 лучший результат = 1970.0
# Эпизод 249:	результат = 400.0	шум = 0.052	 лучший результат = 1970.0
# Эпизод 250:	результат = 350.0	шум = 0.051	 лучший результат = 1970.0
# Эпизод 251:	результат = 580.0	шум = 0.051	 лучший результат = 1970.0
# Эпизод 252:	результат = 220.0	шум = 0.050	 лучший результат = 1970.0
# Эпизод 253:	результат = 430.0	шум = 0.050	 лучший результат = 1970.0
# Эпизод 254:	результат = 190.0	шум = 0.049	 лучший результат = 1970.0
# Эпизод 255:	результат = 350.0	шум = 0.049	 лучший результат = 1970.0
# Эпизод 256:	результат = 790.0	шум = 0.048	 лучший результат = 1970.0
# Эпизод 257:	результат = 210.0	шум = 0.048	 лучший результат = 1970.0
# Эпизод 258:	результат = 400.0	шум = 0.047	 лучший результат = 1970.0
# Эпизод 259:	результат = 580.0	шум = 0.047	 лучший результат = 1970.0
# Эпизод 260:	результат = 330.0	шум = 0.046	 лучший результат = 1970.0
# Эпизод 261:	результат = 860.0	шум = 0.046	 лучший результат = 1970.0
# Эпизод 262:	результат = 1220.0	шум = 0.045	 лучший результат = 1970.0
# Эпизод 263:	результат = 320.0	шум = 0.045	 лучший результат = 1970.0
# Эпизод 264:	результат = 210.0	шум = 0.045	 лучший результат = 1970.0
# Эпизод 265:	результат = 290.0	шум = 0.044	 лучший результат = 1970.0
# Эпизод 266:	результат = 700.0	шум = 0.044	 лучший результат = 1970.0
# Эпизод 267:	результат = 330.0	шум = 0.043	 лучший результат = 1970.0
# Эпизод 268:	результат = 1270.0	шум = 0.043	 лучший результат = 1970.0
# Эпизод 269:	результат = 370.0	шум = 0.042	 лучший результат = 1970.0
# Эпизод 270:	результат = 320.0	шум = 0.042	 лучший результат = 1970.0
# Эпизод 271:	результат = 1230.0	шум = 0.042	 лучший результат = 1970.0
# Эпизод 272:	результат = 370.0	шум = 0.041	 лучший результат = 1970.0
# Эпизод 273:	результат = 380.0	шум = 0.041	 лучший результат = 1970.0
# Эпизод 274:	результат = 320.0	шум = 0.040	 лучший результат = 1970.0
# Эпизод 275:	результат = 330.0	шум = 0.040	 лучший результат = 1970.0
# Эпизод 276:	результат = 370.0	шум = 0.039	 лучший результат = 1970.0
# Эпизод 277:	результат = 920.0	шум = 0.039	 лучший результат = 1970.0
# Эпизод 278:	результат = 210.0	шум = 0.039	 лучший результат = 1970.0
# Эпизод 279:	результат = 360.0	шум = 0.038	 лучший результат = 1970.0
# Эпизод 280:	результат = 380.0	шум = 0.038	 лучший результат = 1970.0
# Эпизод 281:	результат = 540.0	шум = 0.038	 лучший результат = 1970.0
# Эпизод 282:	результат = 440.0	шум = 0.037	 лучший результат = 1970.0
# Эпизод 283:	результат = 290.0	шум = 0.037	 лучший результат = 1970.0
# Эпизод 284:	результат = 300.0	шум = 0.036	 лучший результат = 1970.0
# Эпизод 285:	результат = 550.0	шум = 0.036	 лучший результат = 1970.0
# Эпизод 286:	результат = 440.0	шум = 0.036	 лучший результат = 1970.0
# Эпизод 287:	результат = 990.0	шум = 0.035	 лучший результат = 1970.0
# Эпизод 288:	результат = 280.0	шум = 0.035	 лучший результат = 1970.0
# Эпизод 289:	результат = 290.0	шум = 0.035	 лучший результат = 1970.0
# Эпизод 290:	результат = 390.0	шум = 0.034	 лучший результат = 1970.0
# Эпизод 291:	результат = 400.0	шум = 0.034	 лучший результат = 1970.0
# Эпизод 292:	результат = 330.0	шум = 0.034	 лучший результат = 1970.0
# Эпизод 293:	результат = 400.0	шум = 0.033	 лучший результат = 1970.0
# Эпизод 294:	результат = 400.0	шум = 0.033	 лучший результат = 1970.0
# Эпизод 295:	результат = 410.0	шум = 0.033	 лучший результат = 1970.0
# Эпизод 296:	результат = 330.0	шум = 0.032	 лучший результат = 1970.0
# Эпизод 297:	результат = 930.0	шум = 0.032	 лучший результат = 1970.0
# Эпизод 298:	результат = 280.0	шум = 0.032	 лучший результат = 1970.0
# Эпизод 299:	результат = 320.0	шум = 0.031	 лучший результат = 1970.0
# Эпизод 300:	результат = 350.0	шум = 0.031	 лучший результат = 1970.0
# Эпизод 301:	результат = 310.0	шум = 0.031	 лучший результат = 1970.0
# Эпизод 302:	результат = 430.0	шум = 0.030	 лучший результат = 1970.0
# Эпизод 303:	результат = 280.0	шум = 0.030	 лучший результат = 1970.0
# Эпизод 304:	результат = 380.0	шум = 0.030	 лучший результат = 1970.0
# Эпизод 305:	результат = 700.0	шум = 0.030	 лучший результат = 1970.0
# Эпизод 306:	результат = 580.0	шум = 0.029	 лучший результат = 1970.0
# Эпизод 307:	результат = 580.0	шум = 0.029	 лучший результат = 1970.0
# Эпизод 308:	результат = 280.0	шум = 0.029	 лучший результат = 1970.0
# Эпизод 309:	результат = 320.0	шум = 0.028	 лучший результат = 1970.0
# Эпизод 310:	результат = 340.0	шум = 0.028	 лучший результат = 1970.0
# Эпизод 311:	результат = 570.0	шум = 0.028	 лучший результат = 1970.0
# Эпизод 312:	результат = 370.0	шум = 0.028	 лучший результат = 1970.0
# Эпизод 313:	результат = 430.0	шум = 0.027	 лучший результат = 1970.0
# Эпизод 314:	результат = 580.0	шум = 0.027	 лучший результат = 1970.0
# Эпизод 315:	результат = 580.0	шум = 0.027	 лучший результат = 1970.0
# Эпизод 316:	результат = 550.0	шум = 0.026	 лучший результат = 1970.0
# Эпизод 317:	результат = 320.0	шум = 0.026	 лучший результат = 1970.0
# Эпизод 318:	результат = 330.0	шум = 0.026	 лучший результат = 1970.0
# Эпизод 319:	результат = 310.0	шум = 0.026	 лучший результат = 1970.0
# Эпизод 320:	результат = 280.0	шум = 0.025	 лучший результат = 1970.0
# Эпизод 321:	результат = 280.0	шум = 0.025	 лучший результат = 1970.0
# Эпизод 322:	результат = 580.0	шум = 0.025	 лучший результат = 1970.0
# Эпизод 323:	результат = 390.0	шум = 0.025	 лучший результат = 1970.0
# Эпизод 324:	результат = 580.0	шум = 0.024	 лучший результат = 1970.0
# Эпизод 325:	результат = 320.0	шум = 0.024	 лучший результат = 1970.0
# Эпизод 326:	результат = 430.0	шум = 0.024	 лучший результат = 1970.0
# Эпизод 327:	результат = 320.0	шум = 0.024	 лучший результат = 1970.0
# Эпизод 328:	результат = 310.0	шум = 0.023	 лучший результат = 1970.0
# Эпизод 329:	результат = 290.0	шум = 0.023	 лучший результат = 1970.0
# Эпизод 330:	результат = 1010.0	шум = 0.023	 лучший результат = 1970.0
# Эпизод 331:	результат = 390.0	шум = 0.023	 лучший результат = 1970.0
# Эпизод 332:	результат = 330.0	шум = 0.022	 лучший результат = 1970.0
# Эпизод 333:	результат = 400.0	шум = 0.022	 лучший результат = 1970.0
# Эпизод 334:	результат = 400.0	шум = 0.022	 лучший результат = 1970.0
# Эпизод 335:	результат = 690.0	шум = 0.022	 лучший результат = 1970.0
# Эпизод 336:	результат = 290.0	шум = 0.022	 лучший результат = 1970.0
# Эпизод 337:	результат = 330.0	шум = 0.021	 лучший результат = 1970.0
# Эпизод 338:	результат = 1020.0	шум = 0.021	 лучший результат = 1970.0
# Эпизод 339:	результат = 530.0	шум = 0.021	 лучший результат = 1970.0
# Эпизод 340:	результат = 290.0	шум = 0.021	 лучший результат = 1970.0
# Эпизод 341:	результат = 1020.0	шум = 0.021	 лучший результат = 1970.0
# Эпизод 342:	результат = 350.0	шум = 0.020	 лучший результат = 1970.0
# Эпизод 343:	результат = 580.0	шум = 0.020	 лучший результат = 1970.0
# Эпизод 344:	результат = 940.0	шум = 0.020	 лучший результат = 1970.0
# Эпизод 345:	результат = 330.0	шум = 0.020	 лучший результат = 1970.0
# Эпизод 346:	результат = 280.0	шум = 0.020	 лучший результат = 1970.0
# Эпизод 347:	результат = 390.0	шум = 0.019	 лучший результат = 1970.0
# Эпизод 348:	результат = 390.0	шум = 0.019	 лучший результат = 1970.0
# Эпизод 349:	результат = 690.0	шум = 0.019	 лучший результат = 1970.0
# Эпизод 350:	результат = 280.0	шум = 0.019	 лучший результат = 1970.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 351/500: результат = 2100.0, шум = 0.020
# Эпизод 351:	результат = 2100.0	шум = 0.020	 лучший результат = 2100.0
# Эпизод 352:	результат = 430.0	шум = 0.020	 лучший результат = 2100.0
# Эпизод 353:	результат = 420.0	шум = 0.019	 лучший результат = 2100.0
# Эпизод 354:	результат = 580.0	шум = 0.019	 лучший результат = 2100.0
# Эпизод 355:	результат = 570.0	шум = 0.019	 лучший результат = 2100.0
# Эпизод 356:	результат = 700.0	шум = 0.019	 лучший результат = 2100.0
# Эпизод 357:	результат = 420.0	шум = 0.019	 лучший результат = 2100.0
# Эпизод 358:	результат = 280.0	шум = 0.018	 лучший результат = 2100.0
# Эпизод 359:	результат = 410.0	шум = 0.018	 лучший результат = 2100.0
# Эпизод 360:	результат = 290.0	шум = 0.018	 лучший результат = 2100.0
# Эпизод 361:	результат = 400.0	шум = 0.018	 лучший результат = 2100.0
# Эпизод 362:	результат = 390.0	шум = 0.018	 лучший результат = 2100.0
# Эпизод 363:	результат = 620.0	шум = 0.017	 лучший результат = 2100.0
# Эпизод 364:	результат = 630.0	шум = 0.017	 лучший результат = 2100.0
# Эпизод 365:	результат = 300.0	шум = 0.017	 лучший результат = 2100.0
# Эпизод 366:	результат = 360.0	шум = 0.017	 лучший результат = 2100.0
# Эпизод 367:	результат = 330.0	шум = 0.017	 лучший результат = 2100.0
# Эпизод 368:	результат = 400.0	шум = 0.017	 лучший результат = 2100.0
# Эпизод 369:	результат = 400.0	шум = 0.016	 лучший результат = 2100.0
# Эпизод 370:	результат = 580.0	шум = 0.016	 лучший результат = 2100.0
# Эпизод 371:	результат = 320.0	шум = 0.016	 лучший результат = 2100.0
# Эпизод 372:	результат = 580.0	шум = 0.016	 лучший результат = 2100.0
# Эпизод 373:	результат = 390.0	шум = 0.016	 лучший результат = 2100.0
# Эпизод 374:	результат = 300.0	шум = 0.016	 лучший результат = 2100.0
# Эпизод 375:	результат = 290.0	шум = 0.015	 лучший результат = 2100.0
# Эпизод 376:	результат = 580.0	шум = 0.015	 лучший результат = 2100.0
# Эпизод 377:	результат = 400.0	шум = 0.015	 лучший результат = 2100.0
# Эпизод 378:	результат = 410.0	шум = 0.015	 лучший результат = 2100.0
# Эпизод 379:	результат = 630.0	шум = 0.015	 лучший результат = 2100.0
# Эпизод 380:	результат = 990.0	шум = 0.015	 лучший результат = 2100.0
# Эпизод 381:	результат = 390.0	шум = 0.015	 лучший результат = 2100.0
# Эпизод 382:	результат = 400.0	шум = 0.014	 лучший результат = 2100.0
# Эпизод 383:	результат = 700.0	шум = 0.014	 лучший результат = 2100.0
# Эпизод 384:	результат = 400.0	шум = 0.014	 лучший результат = 2100.0
# Эпизод 385:	результат = 580.0	шум = 0.014	 лучший результат = 2100.0
# Эпизод 386:	результат = 290.0	шум = 0.014	 лучший результат = 2100.0
# Эпизод 387:	результат = 340.0	шум = 0.014	 лучший результат = 2100.0
# Эпизод 388:	результат = 380.0	шум = 0.014	 лучший результат = 2100.0
# Эпизод 389:	результат = 620.0	шум = 0.013	 лучший результат = 2100.0
# Эпизод 390:	результат = 690.0	шум = 0.013	 лучший результат = 2100.0
# Эпизод 391:	результат = 400.0	шум = 0.013	 лучший результат = 2100.0
# Эпизод 392:	результат = 970.0	шум = 0.013	 лучший результат = 2100.0
# Эпизод 393:	результат = 400.0	шум = 0.013	 лучший результат = 2100.0
# Эпизод 394:	результат = 580.0	шум = 0.013	 лучший результат = 2100.0
# Эпизод 395:	результат = 690.0	шум = 0.013	 лучший результат = 2100.0
# Эпизод 396:	результат = 570.0	шум = 0.013	 лучший результат = 2100.0
# Эпизод 397:	результат = 390.0	шум = 0.012	 лучший результат = 2100.0
# Эпизод 398:	результат = 330.0	шум = 0.012	 лучший результат = 2100.0
# Эпизод 399:	результат = 580.0	шум = 0.012	 лучший результат = 2100.0
# Эпизод 400:	результат = 330.0	шум = 0.012	 лучший результат = 2100.0
# Эпизод 401:	результат = 290.0	шум = 0.012	 лучший результат = 2100.0
# Эпизод 402:	результат = 320.0	шум = 0.012	 лучший результат = 2100.0
# Эпизод 403:	результат = 430.0	шум = 0.012	 лучший результат = 2100.0
# Эпизод 404:	результат = 480.0	шум = 0.012	 лучший результат = 2100.0
# Эпизод 405:	результат = 640.0	шум = 0.011	 лучший результат = 2100.0
# Эпизод 406:	результат = 390.0	шум = 0.011	 лучший результат = 2100.0
# Эпизод 407:	результат = 220.0	шум = 0.011	 лучший результат = 2100.0
# Эпизод 408:	результат = 330.0	шум = 0.011	 лучший результат = 2100.0
# Эпизод 409:	результат = 400.0	шум = 0.011	 лучший результат = 2100.0
# Эпизод 410:	результат = 390.0	шум = 0.011	 лучший результат = 2100.0
# Эпизод 411:	результат = 480.0	шум = 0.011	 лучший результат = 2100.0
# Эпизод 412:	результат = 290.0	шум = 0.011	 лучший результат = 2100.0
# Эпизод 413:	результат = 310.0	шум = 0.011	 лучший результат = 2100.0
# Эпизод 414:	результат = 390.0	шум = 0.010	 лучший результат = 2100.0
# Эпизод 415:	результат = 360.0	шум = 0.010	 лучший результат = 2100.0
# Эпизод 416:	результат = 390.0	шум = 0.010	 лучший результат = 2100.0
# Эпизод 417:	результат = 290.0	шум = 0.010	 лучший результат = 2100.0
# Эпизод 418:	результат = 330.0	шум = 0.010	 лучший результат = 2100.0
# Эпизод 419:	результат = 650.0	шум = 0.010	 лучший результат = 2100.0
# Эпизод 420:	результат = 570.0	шум = 0.010	 лучший результат = 2100.0
# Эпизод 421:	результат = 290.0	шум = 0.010	 лучший результат = 2100.0
# Эпизод 422:	результат = 410.0	шум = 0.010	 лучший результат = 2100.0
# Эпизод 423:	результат = 390.0	шум = 0.010	 лучший результат = 2100.0
# Эпизод 424:	результат = 430.0	шум = 0.009	 лучший результат = 2100.0
# Эпизод 425:	результат = 320.0	шум = 0.009	 лучший результат = 2100.0
# Эпизод 426:	результат = 290.0	шум = 0.009	 лучший результат = 2100.0
# Эпизод 427:	результат = 460.0	шум = 0.009	 лучший результат = 2100.0
# Эпизод 428:	результат = 320.0	шум = 0.009	 лучший результат = 2100.0
# Эпизод 429:	результат = 290.0	шум = 0.009	 лучший результат = 2100.0
# Эпизод 430:	результат = 290.0	шум = 0.009	 лучший результат = 2100.0
# Эпизод 431:	результат = 330.0	шум = 0.009	 лучший результат = 2100.0
# Эпизод 432:	результат = 430.0	шум = 0.009	 лучший результат = 2100.0
# Эпизод 433:	результат = 330.0	шум = 0.009	 лучший результат = 2100.0
# Эпизод 434:	результат = 580.0	шум = 0.009	 лучший результат = 2100.0
# Эпизод 435:	результат = 330.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 436:	результат = 430.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 437:	результат = 380.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 438:	результат = 390.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 439:	результат = 290.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 440:	результат = 390.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 441:	результат = 320.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 442:	результат = 470.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 443:	результат = 290.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 444:	результат = 420.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 445:	результат = 330.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 446:	результат = 220.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 447:	результат = 390.0	шум = 0.008	 лучший результат = 2100.0
# Эпизод 448:	результат = 330.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 449:	результат = 320.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 450:	результат = 290.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 451:	результат = 290.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 452:	результат = 420.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 453:	результат = 1040.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 454:	результат = 290.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 455:	результат = 290.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 456:	результат = 580.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 457:	результат = 1040.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 458:	результат = 330.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 459:	результат = 290.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 460:	результат = 570.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 461:	результат = 390.0	шум = 0.007	 лучший результат = 2100.0
# Эпизод 462:	результат = 290.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 463:	результат = 330.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 464:	результат = 330.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 465:	результат = 320.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 466:	результат = 620.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 467:	результат = 580.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 468:	результат = 330.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 469:	результат = 330.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 470:	результат = 300.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 471:	результат = 300.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 472:	результат = 840.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 473:	результат = 330.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 474:	результат = 390.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 475:	результат = 290.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 476:	результат = 580.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 477:	результат = 480.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 478:	результат = 620.0	шум = 0.006	 лучший результат = 2100.0
# Эпизод 479:	результат = 380.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 480:	результат = 330.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 481:	результат = 290.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 482:	результат = 430.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 483:	результат = 690.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 484:	результат = 390.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 485:	результат = 290.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 486:	результат = 940.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 487:	результат = 430.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 488:	результат = 330.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 489:	результат = 330.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 490:	результат = 320.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 491:	результат = 390.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 492:	результат = 330.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 493:	результат = 430.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 494:	результат = 430.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 495:	результат = 380.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 496:	результат = 400.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 497:	результат = 410.0	шум = 0.005	 лучший результат = 2100.0
# Эпизод 498:	результат = 330.0	шум = 0.004	 лучший результат = 2100.0
# Эпизод 499:	результат = 390.0	шум = 0.004	 лучший результат = 2100.0
# Эпизод 500:	результат = 390.0	шум = 0.004	 лучший результат = 2100.0
# Hill Climbing завершён. Лучший результат: 2100.0

# %%
#@title Видео результата Hill Climbing

print("Лучший reward Hill Climbing, достигнутый в тренировке:", r_best)

# Запуск лучшего веса несколько раз для видео, чтобы
# нивелировать стохастичность и показать максимальный результат.
N_EVAL_RUNS = 5
best_eval_reward = -1e9
best_eval_frames = []

env_render_hc = gym.make(GAME_NAME, full_action_space=FULL_ACTION_SPACE, render_mode="rgb_array")

print(f"Проверка лучшего веса на {N_EVAL_RUNS} эпизодах для записи лучшего видео...")

for i in range(N_EVAL_RUNS):
    reward, frames = run_episode(env_render_hc, w_best, record=True)
    print(f"Оценочный прогон {i+1}: reward = {reward:.1f}")

    if reward > best_eval_reward:
        best_eval_reward = reward
        best_eval_frames = frames

env_render_hc.close()

print(f"Максимальный результат для видео Hill Climbing: {best_eval_reward:.1f}")

show_video(best_eval_frames, "best_hill_climbing.mp4")
# Out:
# Лучший reward Hill Climbing, достигнутый в тренировке: 2100.0
# Проверка лучшего веса на 5 эпизодах для записи лучшего видео...
# Оценочный прогон 1: reward = 1900.0
# Оценочный прогон 2: reward = 430.0
# Оценочный прогон 3: reward = 1900.0
# Оценочный прогон 4: reward = 1900.0
# Оценочный прогон 5: reward = 390.0
# Максимальный результат для видео Hill Climbing: 1900.0
# Moviepy - Building video best_hill_climbing.mp4.
# Moviepy - Writing video best_hill_climbing.mp4
# Moviepy - Done !
# Moviepy - video ready best_hill_climbing.mp4
#     <video width=600 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %% [markdown]
# # Вывод по проделанной работе
#
# В рамках данного проекта мной была реализована система обучения агента для игры MsPacman-v5 из среды Gym Atari, обладающей сложным дискретным пространством из девяти действий. Я использовал простую, но вычислительно эффективную линейную политику, где действие выбирается на основе взвешенной суммы пикселей препроцессированного изображения. Для сокращения размерности входных данных и повышения скорости обучения мной был применен агрессивный препроцессинг, включающий перевод кадров в оттенки серого и уменьшение их размера до 32x32 пикселей.
#
# Мной были обучены две модели с использованием стратегий случайного поиска (Random Search, RS) и восхождения на вершину (Hill Climbing, HC). Ключевой оптимизацией для получения достоверных видеорезультатов, учитывая высокую стохастичность среды Atari, стало внедрение множественной оценки: лучший набор весов проверялся на пяти независимых эпизодах.
#
# Сравнивая результаты, я обнаружил, что Random Search достиг максимального результата во время тренировки в 1730 очков, а при последующей оценке смог показать 1800 очков. Однако Hill Climbing, благодаря итеративному и направленному изменению весов, оказался более успешным: мной было зафиксировано вознаграждение в 2100 очков на этапе тренировки. Максимальный результат при оценке видео для Hill Climbing составил 1900 очков.
#
# Эти данные убедительно демонстрируют, что, несмотря на простоту линейной политики, стратегия Hill Climbing, превзошла Random Search в способности находить более оптимальные локальные решения. Разница между лучшим тренировочным результатом (2100) и лучшим оценочным (1900) в Hill Climbing подчеркивает, насколько сильно стохастичность среды влияет на реальную производительность агента в каждом отдельном эпизоде. В целом, мною было подтверждено, что даже для низкоразмерных линейных политик направленный поиск обеспечивает лучшее качество, чем чистая случайность.
