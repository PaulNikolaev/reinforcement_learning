# %% [markdown]
# # Задание
#
# 1. Используя Gym Atari, выберите любую игру с более чем 4-мя действиями.
# 2. Обучите игру на стратегии градиента стратегии (градиентной политики).
# 3. Создайте видео из нескольких игровых эпизодов, в котором модель достигла максимального вознаграждения.

# %%
#@title Установка зависимостей
# !pip install "gymnasium[atari]"
# !pip install autorom[accept-rom-license]
# !pip install moviepy
# !pip install numpy
# !pip install opencv-python
# !pip install torch
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.11.2)
# Collecting autorom[accept-rom-license]
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (8.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (2.32.4)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 8.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2025.11.12)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446709 sha256=5a063331ddfb786147a2c055c36bedecc8948076fd15bf7943ca9b2926fe7f85
#   Stored in directory: /root/.cache/pip/wheels/99/f1/ff/c6966c034a8259164bdc9deb4d1ea839f119474638100e6645
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.6.1
# Requirement already satisfied: moviepy in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.12/dist-packages (from moviepy) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.32.4)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy) (0.1.12)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.0.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.37.2)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy) (0.6.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio<3.0,>=2.5->moviepy) (11.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2025.11.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)

# %%
#@title Импорты
import gymnasium as gym
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from moviepy.editor import ImageSequenceClip
import base64
from IPython.display import HTML, display
import ale_py

gym.register_envs(ale_py)

torch.manual_seed(42)
np.random.seed(42)
# Out:
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:294: SyntaxWarning: invalid escape sequence '\d'
#   lines_video = [l for l in lines if ' Video: ' in l and re.search('\d+x\d+', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:367: SyntaxWarning: invalid escape sequence '\d'
#   rotation_lines = [l for l in lines if 'rotate          :' in l and re.search('\d+$', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:370: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search('\d+$', rotation_line)
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if event.key is 'enter':

# %%
#@title Константы и параметры

GAME_NAME = "ALE/MsPacman-v5"
FULL_ACTION_SPACE = False

MAX_STEPS = 2000          # Длительность эпизода
STATE_SIZE = 32           # Размер препроцессированного изображения 32x32
FLAT_SIZE = STATE_SIZE * STATE_SIZE   # 1024

# Параметры Policy Gradient
GAMMA = 0.99              # Фактор дисконтирования
LEARNING_RATE = 0.001     # Скорость обучения
N_EPISODES = 500         # Количество эпизодов для обучения

# Определение числа действий
env_tmp = gym.make(GAME_NAME, full_action_space=FULL_ACTION_SPACE)
N_ACTIONS = env_tmp.action_space.n
env_tmp.close()

print("Игра:", GAME_NAME)
print("Действий:", N_ACTIONS)
print("Размер входа (32x32):", FLAT_SIZE)
# Out:
# Игра: ALE/MsPacman-v5
# Действий: 9
# Размер входа (32x32): 1024

# %%
#@title Препроцессинг и функция видео

def preprocess(state, size=STATE_SIZE):
    """Grayscale → Resize → Normalize → Tensor."""
    gray = cv2.cvtColor(state, cv2.COLOR_RGB2GRAY)
    small = cv2.resize(gray, (size, size), interpolation=cv2.INTER_AREA)
    # Преобразование в PyTorch Tensor
    tensor = torch.from_numpy(small.flatten()).float() / 255.0
    return tensor

def show_video(frames, filename="episode.mp4", fps=30):
    clip = ImageSequenceClip(frames, fps=fps)
    clip.write_videofile(filename, codec="libx264", audio_codec="aac", verbose=False)

    video_bytes = open(filename, "rb").read()
    encoded = base64.b64encode(video_bytes).decode()

    display(HTML(f"""
    <video width=600 controls>
        <source src="data:video/mp4;base64,{encoded}" type="video/mp4">
    </video>
    """))

# %%
#@title Модель политики (Нейронная сеть)

class PolicyNetwork(nn.Module):
    """Простая нейронная сеть для отображения состояния в распределение действий."""
    def __init__(self, input_size, output_size):
        super(PolicyNetwork, self).__init__()
        # Используем линейный слой для простоты с входным размером 1024 (32*32)
        self.fc1 = nn.Linear(input_size, 128)
        self.fc2 = nn.Linear(128, output_size)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        # Выход - это логиты для распределения действий
        return self.fc2(x)

policy = PolicyNetwork(FLAT_SIZE, N_ACTIONS)
optimizer = optim.Adam(policy.parameters(), lr=LEARNING_RATE)

# %%
#@title Policy Gradient

def run_episode_pg(env, policy, max_steps=MAX_STEPS, record=False):
    state, _ = env.reset()
    log_probs = []
    rewards = []
    frames = []
    total_reward = 0

    for t in range(max_steps):
        if record:
            frames.append(env.render())

        # Выбор действия
        state_tensor = preprocess(state)
        logits = policy(state_tensor)
        # Преобразование логитов в вероятностное распределение и сэмплирование
        dist = torch.distributions.Categorical(logits=logits)
        action = dist.sample()
        log_prob = dist.log_prob(action)
        log_probs.append(log_prob)

        # Шаг в среде
        state, reward, terminated, truncated, _ = env.step(action.item())
        done = terminated or truncated

        rewards.append(reward)
        total_reward += reward
        if done:
            break

    return total_reward, log_probs, rewards, frames

def update_policy(log_probs, rewards):
    # Проверка на пустые списки, если эпизод был слишком коротким.
    if not rewards:
        print("Предупреждение: Эпизод завершился слишком быстро, нет вознаграждений для обновления.")
        return

    # Вычисление дисконтированного суммарного вознаграждения (G_t)
    G = 0
    returns = []

    # Идем в обратном порядке
    for r in reversed(rewards):
        G = r + GAMMA * G
        returns.insert(0, G)

    returns = torch.tensor(returns)

    # Нормализация G_t
    if len(returns) > 1:
        returns = (returns - returns.mean()) / (returns.std() + 1e-9)

    # Вычисление функции потерь для Policy Gradient
    policy_loss = []
    for log_prob, Gt in zip(log_probs, returns):
        policy_loss.append(-log_prob * Gt)

    # Шаг градиентного спуска
    optimizer.zero_grad()
    loss = torch.stack(policy_loss).sum()

    loss.backward()
    optimizer.step()

# %%
#@title Обучение Policy Gradient

env_train = gym.make(GAME_NAME, full_action_space=FULL_ACTION_SPACE)
best_reward_pg = -1e9
best_policy_state = None

print("Запуск Policy Gradient для", GAME_NAME)

for ep in range(N_EPISODES):
    total_reward, log_probs, rewards, _ = run_episode_pg(env_train, policy)

    # Обновление политики
    update_policy(log_probs, rewards)

    if total_reward > best_reward_pg:
        best_reward_pg = total_reward
        # Сохраняем веса лучшей модели
        best_policy_state = policy.state_dict()
        print(f"[НОВЫЙ ЛУЧШИЙ] Эпизод {ep+1}/{N_EPISODES}: результат = {total_reward:.1f}")

    print(f"Эпизод {ep+1}/{N_EPISODES}:\tрезультат = {total_reward:.1f}\tлучший результат = {best_reward_pg:.1f}")

env_train.close()
print("Policy Gradient завершён.")
# Out:
# Запуск Policy Gradient для ALE/MsPacman-v5
# [НОВЫЙ ЛУЧШИЙ] Эпизод 1/500: результат = 220.0
# Эпизод 1/500:	результат = 220.0	лучший результат = 220.0
# Эпизод 2/500:	результат = 190.0	лучший результат = 220.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 3/500: результат = 240.0
# Эпизод 3/500:	результат = 240.0	лучший результат = 240.0
# Эпизод 4/500:	результат = 190.0	лучший результат = 240.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 5/500: результат = 260.0
# Эпизод 5/500:	результат = 260.0	лучший результат = 260.0
# Эпизод 6/500:	результат = 200.0	лучший результат = 260.0
# Эпизод 7/500:	результат = 160.0	лучший результат = 260.0
# Эпизод 8/500:	результат = 230.0	лучший результат = 260.0
# Эпизод 9/500:	результат = 250.0	лучший результат = 260.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 10/500: результат = 270.0
# Эпизод 10/500:	результат = 270.0	лучший результат = 270.0
# Эпизод 11/500:	результат = 110.0	лучший результат = 270.0
# Эпизод 12/500:	результат = 220.0	лучший результат = 270.0
# Эпизод 13/500:	результат = 210.0	лучший результат = 270.0
# Эпизод 14/500:	результат = 180.0	лучший результат = 270.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 15/500: результат = 340.0
# Эпизод 15/500:	результат = 340.0	лучший результат = 340.0
# Эпизод 16/500:	результат = 270.0	лучший результат = 340.0
# Эпизод 17/500:	результат = 170.0	лучший результат = 340.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 18/500: результат = 610.0
# Эпизод 18/500:	результат = 610.0	лучший результат = 610.0
# Эпизод 19/500:	результат = 160.0	лучший результат = 610.0
# Эпизод 20/500:	результат = 590.0	лучший результат = 610.0
# Эпизод 21/500:	результат = 340.0	лучший результат = 610.0
# Эпизод 22/500:	результат = 190.0	лучший результат = 610.0
# Эпизод 23/500:	результат = 100.0	лучший результат = 610.0
# Эпизод 24/500:	результат = 290.0	лучший результат = 610.0
# Эпизод 25/500:	результат = 310.0	лучший результат = 610.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 26/500: результат = 1300.0
# Эпизод 26/500:	результат = 1300.0	лучший результат = 1300.0
# Эпизод 27/500:	результат = 540.0	лучший результат = 1300.0
# Эпизод 28/500:	результат = 250.0	лучший результат = 1300.0
# Эпизод 29/500:	результат = 290.0	лучший результат = 1300.0
# Эпизод 30/500:	результат = 390.0	лучший результат = 1300.0
# Эпизод 31/500:	результат = 170.0	лучший результат = 1300.0
# Эпизод 32/500:	результат = 530.0	лучший результат = 1300.0
# Эпизод 33/500:	результат = 1080.0	лучший результат = 1300.0
# Эпизод 34/500:	результат = 970.0	лучший результат = 1300.0
# Эпизод 35/500:	результат = 150.0	лучший результат = 1300.0
# Эпизод 36/500:	результат = 240.0	лучший результат = 1300.0
# Эпизод 37/500:	результат = 290.0	лучший результат = 1300.0
# Эпизод 38/500:	результат = 250.0	лучший результат = 1300.0
# Эпизод 39/500:	результат = 630.0	лучший результат = 1300.0
# Эпизод 40/500:	результат = 270.0	лучший результат = 1300.0
# Эпизод 41/500:	результат = 140.0	лучший результат = 1300.0
# Эпизод 42/500:	результат = 180.0	лучший результат = 1300.0
# Эпизод 43/500:	результат = 140.0	лучший результат = 1300.0
# Эпизод 44/500:	результат = 370.0	лучший результат = 1300.0
# Эпизод 45/500:	результат = 580.0	лучший результат = 1300.0
# Эпизод 46/500:	результат = 640.0	лучший результат = 1300.0
# Эпизод 47/500:	результат = 250.0	лучший результат = 1300.0
# Эпизод 48/500:	результат = 330.0	лучший результат = 1300.0
# Эпизод 49/500:	результат = 130.0	лучший результат = 1300.0
# Эпизод 50/500:	результат = 160.0	лучший результат = 1300.0
# Эпизод 51/500:	результат = 990.0	лучший результат = 1300.0
# Эпизод 52/500:	результат = 550.0	лучший результат = 1300.0
# Эпизод 53/500:	результат = 140.0	лучший результат = 1300.0
# Эпизод 54/500:	результат = 620.0	лучший результат = 1300.0
# Эпизод 55/500:	результат = 160.0	лучший результат = 1300.0
# Эпизод 56/500:	результат = 180.0	лучший результат = 1300.0
# Эпизод 57/500:	результат = 210.0	лучший результат = 1300.0
# Эпизод 58/500:	результат = 240.0	лучший результат = 1300.0
# Эпизод 59/500:	результат = 230.0	лучший результат = 1300.0
# Эпизод 60/500:	результат = 320.0	лучший результат = 1300.0
# Эпизод 61/500:	результат = 70.0	лучший результат = 1300.0
# Эпизод 62/500:	результат = 410.0	лучший результат = 1300.0
# Эпизод 63/500:	результат = 280.0	лучший результат = 1300.0
# Эпизод 64/500:	результат = 360.0	лучший результат = 1300.0
# Эпизод 65/500:	результат = 200.0	лучший результат = 1300.0
# Эпизод 66/500:	результат = 920.0	лучший результат = 1300.0
# Эпизод 67/500:	результат = 350.0	лучший результат = 1300.0
# Эпизод 68/500:	результат = 360.0	лучший результат = 1300.0
# Эпизод 69/500:	результат = 700.0	лучший результат = 1300.0
# Эпизод 70/500:	результат = 190.0	лучший результат = 1300.0
# Эпизод 71/500:	результат = 220.0	лучший результат = 1300.0
# Эпизод 72/500:	результат = 110.0	лучший результат = 1300.0
# Эпизод 73/500:	результат = 160.0	лучший результат = 1300.0
# Эпизод 74/500:	результат = 230.0	лучший результат = 1300.0
# Эпизод 75/500:	результат = 290.0	лучший результат = 1300.0
# Эпизод 76/500:	результат = 800.0	лучший результат = 1300.0
# Эпизод 77/500:	результат = 100.0	лучший результат = 1300.0
# Эпизод 78/500:	результат = 590.0	лучший результат = 1300.0
# Эпизод 79/500:	результат = 1010.0	лучший результат = 1300.0
# Эпизод 80/500:	результат = 240.0	лучший результат = 1300.0
# Эпизод 81/500:	результат = 320.0	лучший результат = 1300.0
# Эпизод 82/500:	результат = 230.0	лучший результат = 1300.0
# Эпизод 83/500:	результат = 250.0	лучший результат = 1300.0
# Эпизод 84/500:	результат = 510.0	лучший результат = 1300.0
# Эпизод 85/500:	результат = 410.0	лучший результат = 1300.0
# Эпизод 86/500:	результат = 390.0	лучший результат = 1300.0
# Эпизод 87/500:	результат = 290.0	лучший результат = 1300.0
# Эпизод 88/500:	результат = 280.0	лучший результат = 1300.0
# Эпизод 89/500:	результат = 270.0	лучший результат = 1300.0
# Эпизод 90/500:	результат = 360.0	лучший результат = 1300.0
# Эпизод 91/500:	результат = 1000.0	лучший результат = 1300.0
# Эпизод 92/500:	результат = 320.0	лучший результат = 1300.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 93/500: результат = 1620.0
# Эпизод 93/500:	результат = 1620.0	лучший результат = 1620.0
# Эпизод 94/500:	результат = 270.0	лучший результат = 1620.0
# Эпизод 95/500:	результат = 520.0	лучший результат = 1620.0
# Эпизод 96/500:	результат = 340.0	лучший результат = 1620.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 97/500: результат = 1980.0
# Эпизод 97/500:	результат = 1980.0	лучший результат = 1980.0
# Эпизод 98/500:	результат = 190.0	лучший результат = 1980.0
# Эпизод 99/500:	результат = 130.0	лучший результат = 1980.0
# Эпизод 100/500:	результат = 340.0	лучший результат = 1980.0
# Эпизод 101/500:	результат = 500.0	лучший результат = 1980.0
# Эпизод 102/500:	результат = 310.0	лучший результат = 1980.0
# Эпизод 103/500:	результат = 660.0	лучший результат = 1980.0
# Эпизод 104/500:	результат = 550.0	лучший результат = 1980.0
# Эпизод 105/500:	результат = 630.0	лучший результат = 1980.0
# Эпизод 106/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 107/500:	результат = 710.0	лучший результат = 1980.0
# Эпизод 108/500:	результат = 870.0	лучший результат = 1980.0
# Эпизод 109/500:	результат = 430.0	лучший результат = 1980.0
# Эпизод 110/500:	результат = 490.0	лучший результат = 1980.0
# Эпизод 111/500:	результат = 300.0	лучший результат = 1980.0
# Эпизод 112/500:	результат = 570.0	лучший результат = 1980.0
# Эпизод 113/500:	результат = 120.0	лучший результат = 1980.0
# Эпизод 114/500:	результат = 410.0	лучший результат = 1980.0
# Эпизод 115/500:	результат = 1410.0	лучший результат = 1980.0
# Эпизод 116/500:	результат = 290.0	лучший результат = 1980.0
# Эпизод 117/500:	результат = 330.0	лучший результат = 1980.0
# Эпизод 118/500:	результат = 830.0	лучший результат = 1980.0
# Эпизод 119/500:	результат = 370.0	лучший результат = 1980.0
# Эпизод 120/500:	результат = 230.0	лучший результат = 1980.0
# Эпизод 121/500:	результат = 750.0	лучший результат = 1980.0
# Эпизод 122/500:	результат = 640.0	лучший результат = 1980.0
# Эпизод 123/500:	результат = 540.0	лучший результат = 1980.0
# Эпизод 124/500:	результат = 630.0	лучший результат = 1980.0
# Эпизод 125/500:	результат = 380.0	лучший результат = 1980.0
# Эпизод 126/500:	результат = 770.0	лучший результат = 1980.0
# Эпизод 127/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 128/500:	результат = 500.0	лучший результат = 1980.0
# Эпизод 129/500:	результат = 380.0	лучший результат = 1980.0
# Эпизод 130/500:	результат = 1030.0	лучший результат = 1980.0
# Эпизод 131/500:	результат = 420.0	лучший результат = 1980.0
# Эпизод 132/500:	результат = 600.0	лучший результат = 1980.0
# Эпизод 133/500:	результат = 300.0	лучший результат = 1980.0
# Эпизод 134/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 135/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 136/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 137/500:	результат = 920.0	лучший результат = 1980.0
# Эпизод 138/500:	результат = 490.0	лучший результат = 1980.0
# Эпизод 139/500:	результат = 530.0	лучший результат = 1980.0
# Эпизод 140/500:	результат = 880.0	лучший результат = 1980.0
# Эпизод 141/500:	результат = 380.0	лучший результат = 1980.0
# Эпизод 142/500:	результат = 400.0	лучший результат = 1980.0
# Эпизод 143/500:	результат = 610.0	лучший результат = 1980.0
# Эпизод 144/500:	результат = 430.0	лучший результат = 1980.0
# Эпизод 145/500:	результат = 660.0	лучший результат = 1980.0
# Эпизод 146/500:	результат = 760.0	лучший результат = 1980.0
# Эпизод 147/500:	результат = 750.0	лучший результат = 1980.0
# Эпизод 148/500:	результат = 300.0	лучший результат = 1980.0
# Эпизод 149/500:	результат = 550.0	лучший результат = 1980.0
# Эпизод 150/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 151/500:	результат = 520.0	лучший результат = 1980.0
# Эпизод 152/500:	результат = 470.0	лучший результат = 1980.0
# Эпизод 153/500:	результат = 310.0	лучший результат = 1980.0
# Эпизод 154/500:	результат = 480.0	лучший результат = 1980.0
# Эпизод 155/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 156/500:	результат = 490.0	лучший результат = 1980.0
# Эпизод 157/500:	результат = 410.0	лучший результат = 1980.0
# Эпизод 158/500:	результат = 650.0	лучший результат = 1980.0
# Эпизод 159/500:	результат = 490.0	лучший результат = 1980.0
# Эпизод 160/500:	результат = 500.0	лучший результат = 1980.0
# Эпизод 161/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 162/500:	результат = 750.0	лучший результат = 1980.0
# Эпизод 163/500:	результат = 370.0	лучший результат = 1980.0
# Эпизод 164/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 165/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 166/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 167/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 168/500:	результат = 300.0	лучший результат = 1980.0
# Эпизод 169/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 170/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 171/500:	результат = 320.0	лучший результат = 1980.0
# Эпизод 172/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 173/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 174/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 175/500:	результат = 350.0	лучший результат = 1980.0
# Эпизод 176/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 177/500:	результат = 600.0	лучший результат = 1980.0
# Эпизод 178/500:	результат = 510.0	лучший результат = 1980.0
# Эпизод 179/500:	результат = 370.0	лучший результат = 1980.0
# Эпизод 180/500:	результат = 640.0	лучший результат = 1980.0
# Эпизод 181/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 182/500:	результат = 420.0	лучший результат = 1980.0
# Эпизод 183/500:	результат = 520.0	лучший результат = 1980.0
# Эпизод 184/500:	результат = 1730.0	лучший результат = 1980.0
# Эпизод 185/500:	результат = 720.0	лучший результат = 1980.0
# Эпизод 186/500:	результат = 480.0	лучший результат = 1980.0
# Эпизод 187/500:	результат = 1050.0	лучший результат = 1980.0
# Эпизод 188/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 189/500:	результат = 420.0	лучший результат = 1980.0
# Эпизод 190/500:	результат = 550.0	лучший результат = 1980.0
# Эпизод 191/500:	результат = 1920.0	лучший результат = 1980.0
# Эпизод 192/500:	результат = 310.0	лучший результат = 1980.0
# Эпизод 193/500:	результат = 230.0	лучший результат = 1980.0
# Эпизод 194/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 195/500:	результат = 590.0	лучший результат = 1980.0
# Эпизод 196/500:	результат = 570.0	лучший результат = 1980.0
# Эпизод 197/500:	результат = 230.0	лучший результат = 1980.0
# Эпизод 198/500:	результат = 560.0	лучший результат = 1980.0
# Эпизод 199/500:	результат = 430.0	лучший результат = 1980.0
# Эпизод 200/500:	результат = 900.0	лучший результат = 1980.0
# Эпизод 201/500:	результат = 260.0	лучший результат = 1980.0
# Эпизод 202/500:	результат = 570.0	лучший результат = 1980.0
# Эпизод 203/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 204/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 205/500:	результат = 510.0	лучший результат = 1980.0
# Эпизод 206/500:	результат = 480.0	лучший результат = 1980.0
# Эпизод 207/500:	результат = 260.0	лучший результат = 1980.0
# Эпизод 208/500:	результат = 530.0	лучший результат = 1980.0
# Эпизод 209/500:	результат = 260.0	лучший результат = 1980.0
# Эпизод 210/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 211/500:	результат = 530.0	лучший результат = 1980.0
# Эпизод 212/500:	результат = 790.0	лучший результат = 1980.0
# Эпизод 213/500:	результат = 360.0	лучший результат = 1980.0
# Эпизод 214/500:	результат = 570.0	лучший результат = 1980.0
# Эпизод 215/500:	результат = 480.0	лучший результат = 1980.0
# Эпизод 216/500:	результат = 390.0	лучший результат = 1980.0
# Эпизод 217/500:	результат = 860.0	лучший результат = 1980.0
# Эпизод 218/500:	результат = 790.0	лучший результат = 1980.0
# Эпизод 219/500:	результат = 360.0	лучший результат = 1980.0
# Эпизод 220/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 221/500:	результат = 470.0	лучший результат = 1980.0
# Эпизод 222/500:	результат = 900.0	лучший результат = 1980.0
# Эпизод 223/500:	результат = 660.0	лучший результат = 1980.0
# Эпизод 224/500:	результат = 320.0	лучший результат = 1980.0
# Эпизод 225/500:	результат = 590.0	лучший результат = 1980.0
# Эпизод 226/500:	результат = 700.0	лучший результат = 1980.0
# Эпизод 227/500:	результат = 550.0	лучший результат = 1980.0
# Эпизод 228/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 229/500:	результат = 350.0	лучший результат = 1980.0
# Эпизод 230/500:	результат = 630.0	лучший результат = 1980.0
# Эпизод 231/500:	результат = 470.0	лучший результат = 1980.0
# Эпизод 232/500:	результат = 430.0	лучший результат = 1980.0
# Эпизод 233/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 234/500:	результат = 520.0	лучший результат = 1980.0
# Эпизод 235/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 236/500:	результат = 710.0	лучший результат = 1980.0
# Эпизод 237/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 238/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 239/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 240/500:	результат = 210.0	лучший результат = 1980.0
# Эпизод 241/500:	результат = 260.0	лучший результат = 1980.0
# Эпизод 242/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 243/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 244/500:	результат = 400.0	лучший результат = 1980.0
# Эпизод 245/500:	результат = 470.0	лучший результат = 1980.0
# Эпизод 246/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 247/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 248/500:	результат = 960.0	лучший результат = 1980.0
# Эпизод 249/500:	результат = 550.0	лучший результат = 1980.0
# Эпизод 250/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 251/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 252/500:	результат = 290.0	лучший результат = 1980.0
# Эпизод 253/500:	результат = 570.0	лучший результат = 1980.0
# Эпизод 254/500:	результат = 490.0	лучший результат = 1980.0
# Эпизод 255/500:	результат = 340.0	лучший результат = 1980.0
# Эпизод 256/500:	результат = 630.0	лучший результат = 1980.0
# Эпизод 257/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 258/500:	результат = 900.0	лучший результат = 1980.0
# Эпизод 259/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 260/500:	результат = 470.0	лучший результат = 1980.0
# Эпизод 261/500:	результат = 660.0	лучший результат = 1980.0
# Эпизод 262/500:	результат = 420.0	лучший результат = 1980.0
# Эпизод 263/500:	результат = 330.0	лучший результат = 1980.0
# Эпизод 264/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 265/500:	результат = 320.0	лучший результат = 1980.0
# Эпизод 266/500:	результат = 700.0	лучший результат = 1980.0
# Эпизод 267/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 268/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 269/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 270/500:	результат = 1940.0	лучший результат = 1980.0
# Эпизод 271/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 272/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 273/500:	результат = 890.0	лучший результат = 1980.0
# Эпизод 274/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 275/500:	результат = 640.0	лучший результат = 1980.0
# Эпизод 276/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 277/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 278/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 279/500:	результат = 930.0	лучший результат = 1980.0
# Эпизод 280/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 281/500:	результат = 840.0	лучший результат = 1980.0
# Эпизод 282/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 283/500:	результат = 600.0	лучший результат = 1980.0
# Эпизод 284/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 285/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 286/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 287/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 288/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 289/500:	результат = 500.0	лучший результат = 1980.0
# Эпизод 290/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 291/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 292/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 293/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 294/500:	результат = 630.0	лучший результат = 1980.0
# Эпизод 295/500:	результат = 690.0	лучший результат = 1980.0
# Эпизод 296/500:	результат = 850.0	лучший результат = 1980.0
# Эпизод 297/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 298/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 299/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 300/500:	результат = 570.0	лучший результат = 1980.0
# Эпизод 301/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 302/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 303/500:	результат = 850.0	лучший результат = 1980.0
# Эпизод 304/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 305/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 306/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 307/500:	результат = 320.0	лучший результат = 1980.0
# Эпизод 308/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 309/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 310/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 311/500:	результат = 320.0	лучший результат = 1980.0
# Эпизод 312/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 313/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 314/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 315/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 316/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 317/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 318/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 319/500:	результат = 1650.0	лучший результат = 1980.0
# Эпизод 320/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 321/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 322/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 323/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 324/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 325/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 326/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 327/500:	результат = 690.0	лучший результат = 1980.0
# Эпизод 328/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 329/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 330/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 331/500:	результат = 310.0	лучший результат = 1980.0
# Эпизод 332/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 333/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 334/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 335/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 336/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 337/500:	результат = 500.0	лучший результат = 1980.0
# Эпизод 338/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 339/500:	результат = 600.0	лучший результат = 1980.0
# Эпизод 340/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 341/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 342/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 343/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 344/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 345/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 346/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 347/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 348/500:	результат = 540.0	лучший результат = 1980.0
# Эпизод 349/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 350/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 351/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 352/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 353/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 354/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 355/500:	результат = 1270.0	лучший результат = 1980.0
# Эпизод 356/500:	результат = 520.0	лучший результат = 1980.0
# Эпизод 357/500:	результат = 520.0	лучший результат = 1980.0
# Эпизод 358/500:	результат = 840.0	лучший результат = 1980.0
# Эпизод 359/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 360/500:	результат = 500.0	лучший результат = 1980.0
# Эпизод 361/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 362/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 363/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 364/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 365/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 366/500:	результат = 520.0	лучший результат = 1980.0
# Эпизод 367/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 368/500:	результат = 750.0	лучший результат = 1980.0
# Эпизод 369/500:	результат = 510.0	лучший результат = 1980.0
# Эпизод 370/500:	результат = 690.0	лучший результат = 1980.0
# Эпизод 371/500:	результат = 520.0	лучший результат = 1980.0
# Эпизод 372/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 373/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 374/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 375/500:	результат = 560.0	лучший результат = 1980.0
# Эпизод 376/500:	результат = 1640.0	лучший результат = 1980.0
# Эпизод 377/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 378/500:	результат = 530.0	лучший результат = 1980.0
# Эпизод 379/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 380/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 381/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 382/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 383/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 384/500:	результат = 570.0	лучший результат = 1980.0
# Эпизод 385/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 386/500:	результат = 440.0	лучший результат = 1980.0
# Эпизод 387/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 388/500:	результат = 500.0	лучший результат = 1980.0
# Эпизод 389/500:	результат = 840.0	лучший результат = 1980.0
# Эпизод 390/500:	результат = 490.0	лучший результат = 1980.0
# Эпизод 391/500:	результат = 370.0	лучший результат = 1980.0
# Эпизод 392/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 393/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 394/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 395/500:	результат = 620.0	лучший результат = 1980.0
# Эпизод 396/500:	результат = 870.0	лучший результат = 1980.0
# Эпизод 397/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 398/500:	результат = 640.0	лучший результат = 1980.0
# Эпизод 399/500:	результат = 380.0	лучший результат = 1980.0
# Эпизод 400/500:	результат = 710.0	лучший результат = 1980.0
# Эпизод 401/500:	результат = 850.0	лучший результат = 1980.0
# Эпизод 402/500:	результат = 630.0	лучший результат = 1980.0
# Эпизод 403/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 404/500:	результат = 280.0	лучший результат = 1980.0
# Эпизод 405/500:	результат = 240.0	лучший результат = 1980.0
# Эпизод 406/500:	результат = 500.0	лучший результат = 1980.0
# Эпизод 407/500:	результат = 250.0	лучший результат = 1980.0
# Эпизод 408/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 409/500:	результат = 850.0	лучший результат = 1980.0
# Эпизод 410/500:	результат = 400.0	лучший результат = 1980.0
# Эпизод 411/500:	результат = 700.0	лучший результат = 1980.0
# Эпизод 412/500:	результат = 540.0	лучший результат = 1980.0
# Эпизод 413/500:	результат = 320.0	лучший результат = 1980.0
# Эпизод 414/500:	результат = 620.0	лучший результат = 1980.0
# Эпизод 415/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 416/500:	результат = 1060.0	лучший результат = 1980.0
# Эпизод 417/500:	результат = 280.0	лучший результат = 1980.0
# Эпизод 418/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 419/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 420/500:	результат = 780.0	лучший результат = 1980.0
# Эпизод 421/500:	результат = 660.0	лучший результат = 1980.0
# Эпизод 422/500:	результат = 960.0	лучший результат = 1980.0
# Эпизод 423/500:	результат = 650.0	лучший результат = 1980.0
# Эпизод 424/500:	результат = 650.0	лучший результат = 1980.0
# Эпизод 425/500:	результат = 400.0	лучший результат = 1980.0
# Эпизод 426/500:	результат = 380.0	лучший результат = 1980.0
# Эпизод 427/500:	результат = 650.0	лучший результат = 1980.0
# Эпизод 428/500:	результат = 430.0	лучший результат = 1980.0
# Эпизод 429/500:	результат = 430.0	лучший результат = 1980.0
# Эпизод 430/500:	результат = 660.0	лучший результат = 1980.0
# Эпизод 431/500:	результат = 400.0	лучший результат = 1980.0
# Эпизод 432/500:	результат = 350.0	лучший результат = 1980.0
# Эпизод 433/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 434/500:	результат = 1030.0	лучший результат = 1980.0
# Эпизод 435/500:	результат = 360.0	лучший результат = 1980.0
# Эпизод 436/500:	результат = 310.0	лучший результат = 1980.0
# Эпизод 437/500:	результат = 550.0	лучший результат = 1980.0
# Эпизод 438/500:	результат = 560.0	лучший результат = 1980.0
# Эпизод 439/500:	результат = 680.0	лучший результат = 1980.0
# Эпизод 440/500:	результат = 260.0	лучший результат = 1980.0
# Эпизод 441/500:	результат = 360.0	лучший результат = 1980.0
# Эпизод 442/500:	результат = 690.0	лучший результат = 1980.0
# Эпизод 443/500:	результат = 520.0	лучший результат = 1980.0
# Эпизод 444/500:	результат = 330.0	лучший результат = 1980.0
# Эпизод 445/500:	результат = 1160.0	лучший результат = 1980.0
# Эпизод 446/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 447/500:	результат = 840.0	лучший результат = 1980.0
# Эпизод 448/500:	результат = 450.0	лучший результат = 1980.0
# Эпизод 449/500:	результат = 1130.0	лучший результат = 1980.0
# Эпизод 450/500:	результат = 460.0	лучший результат = 1980.0
# Эпизод 451/500:	результат = 670.0	лучший результат = 1980.0
# Эпизод 452/500:	результат = 470.0	лучший результат = 1980.0
# Эпизод 453/500:	результат = 970.0	лучший результат = 1980.0
# Эпизод 454/500:	результат = 530.0	лучший результат = 1980.0
# Эпизод 455/500:	результат = 1210.0	лучший результат = 1980.0
# Эпизод 456/500:	результат = 630.0	лучший результат = 1980.0
# Эпизод 457/500:	результат = 430.0	лучший результат = 1980.0
# Эпизод 458/500:	результат = 520.0	лучший результат = 1980.0
# Эпизод 459/500:	результат = 370.0	лучший результат = 1980.0
# Эпизод 460/500:	результат = 470.0	лучший результат = 1980.0
# Эпизод 461/500:	результат = 490.0	лучший результат = 1980.0
# Эпизод 462/500:	результат = 500.0	лучший результат = 1980.0
# Эпизод 463/500:	результат = 310.0	лучший результат = 1980.0
# [НОВЫЙ ЛУЧШИЙ] Эпизод 464/500: результат = 2680.0
# Эпизод 464/500:	результат = 2680.0	лучший результат = 2680.0
# Эпизод 465/500:	результат = 780.0	лучший результат = 2680.0
# Эпизод 466/500:	результат = 480.0	лучший результат = 2680.0
# Эпизод 467/500:	результат = 420.0	лучший результат = 2680.0
# Эпизод 468/500:	результат = 480.0	лучший результат = 2680.0
# Эпизод 469/500:	результат = 300.0	лучший результат = 2680.0
# Эпизод 470/500:	результат = 500.0	лучший результат = 2680.0
# Эпизод 471/500:	результат = 320.0	лучший результат = 2680.0
# Эпизод 472/500:	результат = 800.0	лучший результат = 2680.0
# Эпизод 473/500:	результат = 990.0	лучший результат = 2680.0
# Эпизод 474/500:	результат = 490.0	лучший результат = 2680.0
# Эпизод 475/500:	результат = 2090.0	лучший результат = 2680.0
# Эпизод 476/500:	результат = 610.0	лучший результат = 2680.0
# Эпизод 477/500:	результат = 770.0	лучший результат = 2680.0
# Эпизод 478/500:	результат = 320.0	лучший результат = 2680.0
# Эпизод 479/500:	результат = 680.0	лучший результат = 2680.0
# Эпизод 480/500:	результат = 360.0	лучший результат = 2680.0
# Эпизод 481/500:	результат = 600.0	лучший результат = 2680.0
# Эпизод 482/500:	результат = 600.0	лучший результат = 2680.0
# Эпизод 483/500:	результат = 600.0	лучший результат = 2680.0
# Эпизод 484/500:	результат = 320.0	лучший результат = 2680.0
# Эпизод 485/500:	результат = 720.0	лучший результат = 2680.0
# Эпизод 486/500:	результат = 480.0	лучший результат = 2680.0
# Эпизод 487/500:	результат = 210.0	лучший результат = 2680.0
# Эпизод 488/500:	результат = 1110.0	лучший результат = 2680.0
# Эпизод 489/500:	результат = 1080.0	лучший результат = 2680.0
# Эпизод 490/500:	результат = 290.0	лучший результат = 2680.0
# Эпизод 491/500:	результат = 210.0	лучший результат = 2680.0
# Эпизод 492/500:	результат = 1100.0	лучший результат = 2680.0
# Эпизод 493/500:	результат = 430.0	лучший результат = 2680.0
# Эпизод 494/500:	результат = 210.0	лучший результат = 2680.0
# Эпизод 495/500:	результат = 490.0	лучший результат = 2680.0
# Эпизод 496/500:	результат = 340.0	лучший результат = 2680.0
# Эпизод 497/500:	результат = 640.0	лучший результат = 2680.0
# Эпизод 498/500:	результат = 650.0	лучший результат = 2680.0
# Эпизод 499/500:	результат = 630.0	лучший результат = 2680.0
# Эпизод 500/500:	результат = 1330.0	лучший результат = 2680.0
# Policy Gradient завершён.

# %%
#@title Видео результата Policy Gradient

print("Лучший результат Policy Gradient, достигнутый в тренировке:", best_reward_pg)

if best_policy_state:
    # Загружаем лучшую модель
    policy.load_state_dict(best_policy_state)

    # Запуск лучшего веса несколько раз для видео
    N_EVAL_RUNS = 5
    best_eval_reward_pg = -1e9
    best_eval_frames_pg = []

    env_render_pg = gym.make(GAME_NAME, full_action_space=FULL_ACTION_SPACE, render_mode="rgb_array")

    print(f"Проверка лучшей политики на {N_EVAL_RUNS} эпизодах для записи лучшего видео...")

    for i in range(N_EVAL_RUNS):
        # Используем обученную политику
        reward, _, _, frames = run_episode_pg(env_render_pg, policy, record=True)
        print(f"Оценочный прогон {i+1}: reward = {reward:.1f}")

        if reward > best_eval_reward_pg:
            best_eval_reward_pg = reward
            best_eval_frames_pg = frames

    env_render_pg.close()

    print(f"Максимальный результат для видео Policy Gradient: {best_eval_reward_pg:.1f}")

    show_video(best_eval_frames_pg, "best_policy_gradient.mp4")
else:
    print("Не удалось найти лучшую политику для видео.")
# Out:
# Лучший результат Policy Gradient, достигнутый в тренировке: 2680.0
# Проверка лучшей политики на 5 эпизодах для записи лучшего видео...
# Оценочный прогон 1: reward = 1140.0
# Оценочный прогон 2: reward = 950.0
# Оценочный прогон 3: reward = 1280.0
# Оценочный прогон 4: reward = 760.0
# Оценочный прогон 5: reward = 320.0
# Максимальный результат для видео Policy Gradient: 1280.0
# Moviepy - Building video best_policy_gradient.mp4.
# Moviepy - Writing video best_policy_gradient.mp4
# Moviepy - Done !
# Moviepy - video ready best_policy_gradient.mp4
#     <video width=600 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %% [markdown]
# ## Вывод по проделанной работе
#
# Я применил алгоритм Policy Gradient для решения задачи управления в среде Gym Atari MsPacman-v5, используя PyTorch для построения нейронной сети политики. Я реализовал базовый алгоритм, который для обновления весов требует полного эпизода игры. В качестве оптимизации я применил нормализацию кумулятивных вознаграждений и использовал оптимизатор Adam с небольшой скоростью обучения.
#
# Наблюдение за видеозаписями эпизодов и анализ финальных результатов показали, что производительность оказалась значительно ниже ожидаемой, а максимальное вознаграждение, достигнутое в тренировке, не было стабильно воспроизведено в оценочных прогонах. Главной проблемой стала высокая дисперсия метода: поскольку градиент основан на суммарном дисконтированном вознаграждении всей последующей траектории, даже небольшая случайность в игре MsPacman приводила к резким и нестабильным обновлениям политики. Отсутствие более совершенного механизм оценки также не позволяло эффективно снизить дисперсию, из-за чего агент не мог надежно отличить действительно хорошие действия от просто удачного эпизода. Таким образом, алгоритм Policy Gradient плохо подходит для этой задачи из-за высокой дисперсии и неэффективного использования данных.
#
# При создании видео, мной было установлено, что лучший результат 2680.0 является выбросом, полученным за счет исключительно удачного стечения обстоятельств в высокодисперсном обучении. Политика, сохраненная с этим весом, не обладает обобщающей способностью, поскольку она оптимизирована под этот шумный, единичный эпизод, что объясняет, почему в оценочных прогонах результат падает до более стабильного уровня 1280.0.
